# %%
import pandas as pd
from sklearn import preprocessing
from sklearn.decomposition import PCA
import numpy as np
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
# 加载数据
file_path_Mix_dataset_One_Hot = r"D:\Download\zyFile\Cyberthreat_Cognitive_System\CTCS_Code\attack_datasets\NSL-KDD\Mix_dataset_One_Hot.csv"
file_path_Mix_dataset_One_Hot_LDA = r"D:\Download\zyFile\Cyberthreat_Cognitive_System\CTCS_Code\attack_datasets\NSL-KDD\Mix_dataset_One_Hot_LDA.csv"
file_path_Mix_dataset_One_Hot_PCA = r"D:\Download\zyFile\Cyberthreat_Cognitive_System\CTCS_Code\attack_datasets\NSL-KDD\Mix_dataset_One_Hot_PCA.csv"
file_path_Mix_dataset_One_Hot_MI = r"D:\Download\zyFile\Cyberthreat_Cognitive_System\CTCS_Code\attack_datasets\NSL-KDD\Mix_dataset_One_Hot_MI.csv"
file_path_Mix_dataset_One_Hot_Pearson = r"D:\Download\zyFile\Cyberthreat_Cognitive_System\CTCS_Code\attack_datasets\NSL-KDD\Mix_dataset_One_Hot_Pearson.csv"

file_path_Mix_dataset_Label_Encoding = r"D:\Download\zyFile\Cyberthreat_Cognitive_System\CTCS_Code\attack_datasets\NSL-KDD\Mix_dataset_Label_Encoding.csv"
file_path_Mix_dataset_Label_Encoding_LDA = r"D:\Download\zyFile\Cyberthreat_Cognitive_System\CTCS_Code\attack_datasets\NSL-KDD\Mix_dataset_Label_Encoding_LDA.csv"
file_path_Mix_dataset_Label_Encoding_PCA = r"D:\Download\zyFile\Cyberthreat_Cognitive_System\CTCS_Code\attack_datasets\NSL-KDD\Mix_dataset_Label_Encoding_PCA.csv"
file_path_Mix_dataset_Label_Encoding_MI = r"D:\Download\zyFile\Cyberthreat_Cognitive_System\CTCS_Code\attack_datasets\NSL-KDD\Mix_dataset_Label_Encoding_MI.csv"
file_path_Mix_dataset_Label_Encoding_Pearson = r"D:\Download\zyFile\Cyberthreat_Cognitive_System\CTCS_Code\attack_datasets\NSL-KDD\Mix_dataset_Label_Encoding_Pearson.csv"
# 加载数据
final_data = pd.read_csv(file_path_Mix_dataset_One_Hot_MI, header=0)
final_data.head()
# Out:
#    service_eco_i  srv_rerror_rate  duration  dst_host_srv_rerror_rate  \
# 0      -0.183696        -0.405192 -0.112481                 -0.406815
# 1      -0.183696        -0.405192 -0.112481                 -0.406815
# 2      -0.183696        -0.405192 -0.112481                 -0.406815
# 3      -0.183696        -0.405192 -0.112481                 -0.376989
# 4      -0.183696        -0.405192 -0.112481                 -0.406815
#
#    rerror_rate  service_private  dst_host_rerror_rate  srv_diff_host_rate  \
# 0     -0.40646        -0.467387             -0.267151           -0.376389
# 1     -0.40646        -0.467387             -0.422074           -0.376389
# 2     -0.40646         2.139552             -0.422074           -0.376389
# 3     -0.40646        -0.467387             -0.422074           -0.376389
# 4     -0.40646        -0.467387             -0.422074           -0.028744
#
#    srv_count  dst_host_count  ...   flag_SF  dst_host_same_srv_rate  \
# 0  -0.348310       -0.344349  ...  0.808391               -0.813554
# 1  -0.361578        0.721338  ...  0.808391               -1.192968
# 2  -0.295238        0.721338  ... -1.237025               -0.969783
# 3  -0.308506       -1.562277  ...  0.808391                1.038878
# 4   0.049729        0.721338  ...  0.808391                1.038878
#
#    dst_host_srv_count     count  dst_host_diff_srv_rate  same_srv_rate  \
# 0           -0.849240 -0.696611               -0.278736       0.749108
# 1           -1.065006 -0.602401                2.657874      -1.358363
# 2           -0.840250  0.339700               -0.175697      -1.427085
# 3            1.218511 -0.670918               -0.433294       0.749108
# 4            1.218511 -0.456804               -0.433294       0.749108
#
#    diff_srv_rate  dst_bytes  src_bytes  label
# 0      -0.348092  -0.004614  -0.007346      0
# 1       0.422462  -0.004614  -0.007409      0
# 2       0.011499  -0.004614  -0.007436      1
# 3      -0.348092  -0.002413  -0.007394      0
# 4      -0.348092  -0.004501  -0.007400      0
#
# [5 rows x 29 columns]

# %%
X = final_data.iloc[:, :-1].values # 除目标属性外的数据集
y = final_data.iloc[:, -1].values   # 目标属性（标签）

# %%
# 分割数据集
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42, stratify=y)

# %%
# from collections import Counter
# from imblearn.over_sampling import SMOTE
# 
# # 初始化 SMOTE 对象
# smote = SMOTE()
# 
# # 对训练集进行重采样
# X_train, y_train  = smote.fit_resample(X_train, y_train)
# 
# # 打印重采样后的数据规模
# print(f'重采样后的数据规模')
# print(f'X_train_resampled shape: {X_train.shape}')
# print(f'y_train_resampled shape: {y_train.shape}')
# print(Counter(y_train))
# Out:
# 重采样后的数据规模
# X_train_resampled shape: (288950, 28)
# y_train_resampled shape: (288950,)
# Counter({1: 57790, 0: 57790, 3: 57790, 2: 57790, 4: 57790})

# %%
from collections import Counter
from imblearn.over_sampling import ADASYN

# 初始化 ADASYN 对象
adasyn = ADASYN()

# 对训练集进行重采样
X_train, y_train = adasyn.fit_resample(X_train, y_train)

# 打印重采样后的数据规模
print(f'重采样后的数据规模')
print(f'X_train_resampled shape: {X_train.shape}')
print(f'y_train_resampled shape: {y_train.shape}')
print(Counter(y_train))
# Out:
# 重采样后的数据规模
# X_train_resampled shape: (288997, 28)
# y_train_resampled shape: (288997,)
# Counter({3: 57880, 0: 57790, 2: 57789, 1: 57770, 4: 57768})

# %%
# 重塑训练数据和测试数据以适配模型的输入 (假设每个样本只有单个时间步长)
x_train = np.reshape(X_train, (X_train.shape[0], 1, X_train.shape[1]))
x_test = np.reshape(X_test, (X_test.shape[0], 1, X_test.shape[1]))

# %%
# 对于多分类问题，标签y需要进行one-hot编码
from keras.utils import np_utils
y_train = np_utils.to_categorical(y_train)
y_test = np_utils.to_categorical(y_test)

# %%
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout, Bidirectional

# 初始化顺序模型
model = Sequential()

# 修改这里的input_shape以匹配实际的特征数量
model.add(Bidirectional(LSTM(100, return_sequences=True), input_shape=(1, 28)))
model.add(Dropout(0.5))
# 添加更多的LSTM层或其他类型的层
model.add(Bidirectional(LSTM(50)))
model.add(Dropout(0.5))

# 输出层，使用softmax激活函数，适用于多分类问题
model.add(Dense(5, activation='softmax'))
# 编译模型
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# 打印模型概述信息
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional (Bidirectiona  (None, 1, 200)           103200
#  l)
#
#  dropout (Dropout)           (None, 1, 200)            0
#
#  bidirectional_1 (Bidirectio  (None, 100)              100400
#  nal)
#
#  dropout_1 (Dropout)         (None, 100)               0
#
#  dense (Dense)               (None, 5)                 505
#
# =================================================================
# Total params: 204,105
# Trainable params: 204,105
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger

# 定义模型检查点回调
checkpoint = ModelCheckpoint(
    r"D:\Download\zyFile\Cyberthreat_Cognitive_System\CTCS_Code\attack_datasets\NSL-KDD\Model\NSL-KDD\AUG\LSTM\Mix_dataset_One_Hot_MI_ADASYN.h5",
    monitor='val_accuracy',  # 监视验证集的准确率
    verbose=1,               # 打印出详细日志
    save_best_only=True,     # 只保存在验证集上准确率最高的模型
    mode='max'               # 'max'表示监视的指标（val_accuracy）需要被最大化
)

# 定义CSV日志记录回调
csv_logger = CSVLogger(
    r"D:\Download\zyFile\Cyberthreat_Cognitive_System\CTCS_Code\attack_datasets\NSL-KDD\Model\NSL-KDD\AUG\LSTM\CSV\Mix_dataset_One_Hot_MI_ADASYN.csv",
    separator=",",
    append=False  # 每次开始训练都重新写日志文件
)

# 使用调整后的fit方法开始训练
history = model.fit(
    x_train,
    y_train,
    epochs=300,  # 训练100个epoch
    batch_size=2500,  # 每个批次的样本数
    validation_split=0.2,  # 使用20%的训练数据作为验证集
    callbacks=[checkpoint, csv_logger]  # 使用回调函数
)
# Out:
# Epoch 1/300
# 84/93 [==========================>...] - ETA: 0s - loss: 0.9389 - accuracy: 0.7181
# Epoch 00001: val_accuracy improved from -inf to 0.00209, saving model to D:\Download\zyFile\Cyberthreat_Cognitive_System\CTCS_Code\attack_datasets\NSL-KDD\Model\NSL-KDD\AUG\LSTM\Mix_dataset_One_Hot_MI_ADASYN.h5
# 93/93 [==============================] - 4s 14ms/step - loss: 0.9066 - accuracy: 0.7253 - val_loss: 4.8902 - val_accuracy: 0.0021
# Epoch 2/300
# 89/93 [===========================>..] - ETA: 0s - loss: 0.5139 - accuracy: 0.8154
# Epoch 00002: val_accuracy did not improve from 0.00209
# 93/93 [==============================] - 1s 6ms/step - loss: 0.5122 - accuracy: 0.8158 - val_loss: 5.5286 - val_accuracy: 0.0021
# Epoch 3/300
# 88/93 [===========================>..] - ETA: 0s - loss: 0.4189 - accuracy: 0.8448
# Epoch 00003: val_accuracy did not improve from 0.00209
# 93/93 [==============================] - 1s 6ms/step - loss: 0.4173 - accuracy: 0.8454 - val_loss: 6.0372 - val_accuracy: 0.0021
# Epoch 4/300
# 93/93 [==============================] - ETA: 0s - loss: 0.3674 - accuracy: 0.8650
# Epoch 00004: val_accuracy did not improve from 0.00209
# 93/93 [==============================] - 1s 6ms/step - loss: 0.3674 - accuracy: 0.8650 - val_loss: 6.3094 - val_accuracy: 0.0021
# Epoch 5/300
# 93/93 [==============================] - ETA: 0s - loss: 0.3349 - accuracy: 0.8777
# Epoch 00005: val_accuracy did not improve from 0.00209
# 93/93 [==============================] - 1s 6ms/step - loss: 0.3349 - accuracy: 0.8777 - val_loss: 6.5133 - val_accuracy: 0.0021
# Epoch 6/300
# 90/93 [============================>.] - ETA: 0s - loss: 0.3125 - accuracy: 0.8864
# Epoch 00006: val_accuracy did not improve from 0.00209
# 93/93 [==============================] - 1s 6ms/step - loss: 0.3119 - accuracy: 0.8867 - val_loss: 6.5842 - val_accuracy: 0.0021
# Epoch 7/300
# 93/93 [==============================] - ETA: 0s - loss: 0.2935 - accuracy: 0.8949
# Epoch 00007: val_accuracy did not improve from 0.00209
# 93/93 [==============================] - 1s 6ms/step - loss: 0.2935 - accuracy: 0.8949 - val_loss: 6.7892 - val_accuracy: 0.0021
# Epoch 8/300
# 90/93 [============================>.] - ETA: 0s - loss: 0.2787 - accuracy: 0.9009
# Epoch 00008: val_accuracy did not improve from 0.00209
# 93/93 [==============================] - 1s 6ms/step - loss: 0.2782 - accuracy: 0.9010 - val_loss: 7.0558 - val_accuracy: 0.0021
# Epoch 9/300
# 84/93 [==========================>...] - ETA: 0s - loss: 0.2673 - accuracy: 0.9056
# Epoch 00009: val_accuracy did not improve from 0.00209
# 93/93 [==============================] - 1s 6ms/step - loss: 0.2671 - accuracy: 0.9057 - val_loss: 6.6291 - val_accuracy: 0.0021
# Epoch 10/300
# 89/93 [===========================>..] - ETA: 0s - loss: 0.2547 - accuracy: 0.9109
# Epoch 00010: val_accuracy did not improve from 0.00209
# 93/93 [==============================] - 1s 6ms/step - loss: 0.2545 - accuracy: 0.9109 - val_loss: 7.0009 - val_accuracy: 0.0021
# Epoch 11/300
# 92/93 [============================>.] - ETA: 0s - loss: 0.2450 - accuracy: 0.9140
# Epoch 00011: val_accuracy did not improve from 0.00209
# 93/93 [==============================] - 1s 7ms/step - loss: 0.2448 - accuracy: 0.9141 - val_loss: 6.9713 - val_accuracy: 0.0021
# Epoch 12/300
# 88/93 [===========================>..] - ETA: 0s - loss: 0.2355 - accuracy: 0.9176
# Epoch 00012: val_accuracy did not improve from 0.00209
# 93/93 [==============================] - 1s 6ms/step - loss: 0.2353 - accuracy: 0.9177 - val_loss: 6.7934 - val_accuracy: 0.0021
# Epoch 13/300
# 92/93 [============================>.] - ETA: 0s - loss: 0.2277 - accuracy: 0.9209
# Epoch 00013: val_accuracy did not improve from 0.00209
# 93/93 [==============================] - 1s 6ms/step - loss: 0.2276 - accuracy: 0.9209 - val_loss: 7.0873 - val_accuracy: 0.0021
# Epoch 14/300
# 91/93 [============================>.] - ETA: 0s - loss: 0.2204 - accuracy: 0.9234
# Epoch 00014: val_accuracy did not improve from 0.00209
# 93/93 [==============================] - 1s 6ms/step - loss: 0.2202 - accuracy: 0.9236 - val_loss: 7.0217 - val_accuracy: 0.0021
# Epoch 15/300
# 92/93 [============================>.] - ETA: 0s - loss: 0.2124 - accuracy: 0.9264
# Epoch 00015: val_accuracy did not improve from 0.00209
# 93/93 [==============================] - 1s 6ms/step - loss: 0.2126 - accuracy: 0.9264 - val_loss: 6.8531 - val_accuracy: 0.0021
# Epoch 16/300
# 93/93 [==============================] - ETA: 0s - loss: 0.2079 - accuracy: 0.9284
# Epoch 00016: val_accuracy did not improve from 0.00209
# 93/93 [==============================] - 1s 6ms/step - loss: 0.2079 - accuracy: 0.9284 - val_loss: 6.8673 - val_accuracy: 0.0021
# Epoch 17/300
# 91/93 [============================>.] - ETA: 0s - loss: 0.2020 - accuracy: 0.9305
# Epoch 00017: val_accuracy did not improve from 0.00209
# 93/93 [==============================] - 1s 6ms/step - loss: 0.2019 - accuracy: 0.9306 - val_loss: 6.8253 - val_accuracy: 0.0021
# Epoch 18/300
# 89/93 [===========================>..] - ETA: 0s - loss: 0.1959 - accuracy: 0.9329
# Epoch 00018: val_accuracy did not improve from 0.00209
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1960 - accuracy: 0.9328 - val_loss: 7.0699 - val_accuracy: 0.0021
# Epoch 19/300
# 92/93 [============================>.] - ETA: 0s - loss: 0.1923 - accuracy: 0.9337
# Epoch 00019: val_accuracy did not improve from 0.00209
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1923 - accuracy: 0.9337 - val_loss: 7.0938 - val_accuracy: 0.0021
# Epoch 20/300
# 89/93 [===========================>..] - ETA: 0s - loss: 0.1886 - accuracy: 0.9351
# Epoch 00020: val_accuracy did not improve from 0.00209
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1885 - accuracy: 0.9352 - val_loss: 7.2477 - val_accuracy: 0.0021
# Epoch 21/300
# 88/93 [===========================>..] - ETA: 0s - loss: 0.1836 - accuracy: 0.9371
# Epoch 00021: val_accuracy did not improve from 0.00209
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1835 - accuracy: 0.9371 - val_loss: 7.0515 - val_accuracy: 0.0021
# Epoch 22/300
# 92/93 [============================>.] - ETA: 0s - loss: 0.1802 - accuracy: 0.9381
# Epoch 00022: val_accuracy did not improve from 0.00209
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1801 - accuracy: 0.9382 - val_loss: 7.1825 - val_accuracy: 0.0021
# Epoch 23/300
# 92/93 [============================>.] - ETA: 0s - loss: 0.1767 - accuracy: 0.9391
# Epoch 00023: val_accuracy did not improve from 0.00209
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1768 - accuracy: 0.9391 - val_loss: 7.2144 - val_accuracy: 0.0021
# Epoch 24/300
# 92/93 [============================>.] - ETA: 0s - loss: 0.1743 - accuracy: 0.9404
# Epoch 00024: val_accuracy did not improve from 0.00209
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1744 - accuracy: 0.9404 - val_loss: 6.8839 - val_accuracy: 0.0021
# Epoch 25/300
# 91/93 [============================>.] - ETA: 0s - loss: 0.1705 - accuracy: 0.9417
# Epoch 00025: val_accuracy did not improve from 0.00209
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1704 - accuracy: 0.9417 - val_loss: 7.0659 - val_accuracy: 0.0021
# Epoch 26/300
# 92/93 [============================>.] - ETA: 0s - loss: 0.1680 - accuracy: 0.9426
# Epoch 00026: val_accuracy did not improve from 0.00209
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1681 - accuracy: 0.9425 - val_loss: 6.9611 - val_accuracy: 0.0021
# Epoch 27/300
# 90/93 [============================>.] - ETA: 0s - loss: 0.1653 - accuracy: 0.9435
# Epoch 00027: val_accuracy did not improve from 0.00209
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1656 - accuracy: 0.9434 - val_loss: 7.0054 - val_accuracy: 0.0021
# Epoch 28/300
# 90/93 [============================>.] - ETA: 0s - loss: 0.1631 - accuracy: 0.9441
# Epoch 00028: val_accuracy did not improve from 0.00209
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1630 - accuracy: 0.9441 - val_loss: 6.9587 - val_accuracy: 0.0021
# Epoch 29/300
# 88/93 [===========================>..] - ETA: 0s - loss: 0.1594 - accuracy: 0.9464
# Epoch 00029: val_accuracy did not improve from 0.00209
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1595 - accuracy: 0.9463 - val_loss: 6.9638 - val_accuracy: 0.0021
# Epoch 30/300
# 87/93 [===========================>..] - ETA: 0s - loss: 0.1588 - accuracy: 0.9458
# Epoch 00030: val_accuracy did not improve from 0.00209
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1583 - accuracy: 0.9460 - val_loss: 6.9193 - val_accuracy: 0.0021
# Epoch 31/300
# 87/93 [===========================>..] - ETA: 0s - loss: 0.1561 - accuracy: 0.9464
# Epoch 00031: val_accuracy did not improve from 0.00209
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1562 - accuracy: 0.9464 - val_loss: 7.0076 - val_accuracy: 0.0021
# Epoch 32/300
# 85/93 [==========================>...] - ETA: 0s - loss: 0.1538 - accuracy: 0.9472
# Epoch 00032: val_accuracy did not improve from 0.00209
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1536 - accuracy: 0.9474 - val_loss: 6.7771 - val_accuracy: 0.0021
# Epoch 33/300
# 88/93 [===========================>..] - ETA: 0s - loss: 0.1526 - accuracy: 0.9475
# Epoch 00033: val_accuracy did not improve from 0.00209
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1524 - accuracy: 0.9475 - val_loss: 6.8331 - val_accuracy: 0.0021
# Epoch 34/300
# 88/93 [===========================>..] - ETA: 0s - loss: 0.1499 - accuracy: 0.9488
# Epoch 00034: val_accuracy did not improve from 0.00209
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1499 - accuracy: 0.9488 - val_loss: 6.8711 - val_accuracy: 0.0021
# Epoch 35/300
# 89/93 [===========================>..] - ETA: 0s - loss: 0.1499 - accuracy: 0.9492
# Epoch 00035: val_accuracy did not improve from 0.00209
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1495 - accuracy: 0.9494 - val_loss: 6.8091 - val_accuracy: 0.0021
# Epoch 36/300
# 85/93 [==========================>...] - ETA: 0s - loss: 0.1465 - accuracy: 0.9501
# Epoch 00036: val_accuracy did not improve from 0.00209
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1465 - accuracy: 0.9501 - val_loss: 6.8239 - val_accuracy: 0.0021
# Epoch 37/300
# 89/93 [===========================>..] - ETA: 0s - loss: 0.1451 - accuracy: 0.9505
# Epoch 00037: val_accuracy did not improve from 0.00209
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1450 - accuracy: 0.9505 - val_loss: 6.8474 - val_accuracy: 0.0021
# Epoch 38/300
# 92/93 [============================>.] - ETA: 0s - loss: 0.1448 - accuracy: 0.9505
# Epoch 00038: val_accuracy did not improve from 0.00209
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1447 - accuracy: 0.9505 - val_loss: 6.6328 - val_accuracy: 0.0021
# Epoch 39/300
# 87/93 [===========================>..] - ETA: 0s - loss: 0.1421 - accuracy: 0.9515
# Epoch 00039: val_accuracy did not improve from 0.00209
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1424 - accuracy: 0.9514 - val_loss: 6.6683 - val_accuracy: 0.0021
# Epoch 40/300
# 92/93 [============================>.] - ETA: 0s - loss: 0.1418 - accuracy: 0.9515
# Epoch 00040: val_accuracy did not improve from 0.00209
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1417 - accuracy: 0.9516 - val_loss: 6.6985 - val_accuracy: 0.0021
# Epoch 41/300
# 90/93 [============================>.] - ETA: 0s - loss: 0.1399 - accuracy: 0.9521
# Epoch 00041: val_accuracy did not improve from 0.00209
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1397 - accuracy: 0.9521 - val_loss: 6.6591 - val_accuracy: 0.0021
# Epoch 42/300
# 92/93 [============================>.] - ETA: 0s - loss: 0.1386 - accuracy: 0.9530
# Epoch 00042: val_accuracy did not improve from 0.00209
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1386 - accuracy: 0.9530 - val_loss: 6.4410 - val_accuracy: 0.0021
# Epoch 43/300
# 83/93 [=========================>....] - ETA: 0s - loss: 0.1371 - accuracy: 0.9530
# Epoch 00043: val_accuracy did not improve from 0.00209
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1373 - accuracy: 0.9530 - val_loss: 6.3850 - val_accuracy: 0.0021
# Epoch 44/300
# 91/93 [============================>.] - ETA: 0s - loss: 0.1353 - accuracy: 0.9534
# Epoch 00044: val_accuracy did not improve from 0.00209
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1353 - accuracy: 0.9535 - val_loss: 6.6748 - val_accuracy: 0.0021
# Epoch 45/300
# 92/93 [============================>.] - ETA: 0s - loss: 0.1343 - accuracy: 0.9542
# Epoch 00045: val_accuracy did not improve from 0.00209
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1343 - accuracy: 0.9542 - val_loss: 6.5778 - val_accuracy: 0.0021
# Epoch 46/300
# 85/93 [==========================>...] - ETA: 0s - loss: 0.1336 - accuracy: 0.9538
# Epoch 00046: val_accuracy did not improve from 0.00209
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1332 - accuracy: 0.9540 - val_loss: 6.5489 - val_accuracy: 0.0021
# Epoch 47/300
# 87/93 [===========================>..] - ETA: 0s - loss: 0.1328 - accuracy: 0.9545
# Epoch 00047: val_accuracy did not improve from 0.00209
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1334 - accuracy: 0.9544 - val_loss: 6.4897 - val_accuracy: 0.0021
# Epoch 48/300
# 84/93 [==========================>...] - ETA: 0s - loss: 0.1316 - accuracy: 0.9554
# Epoch 00048: val_accuracy did not improve from 0.00209
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1311 - accuracy: 0.9557 - val_loss: 6.5119 - val_accuracy: 0.0021
# Epoch 49/300
# 92/93 [============================>.] - ETA: 0s - loss: 0.1300 - accuracy: 0.9556
# Epoch 00049: val_accuracy did not improve from 0.00209
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1300 - accuracy: 0.9556 - val_loss: 6.3482 - val_accuracy: 0.0021
# Epoch 50/300
# 89/93 [===========================>..] - ETA: 0s - loss: 0.1302 - accuracy: 0.9554
# Epoch 00050: val_accuracy did not improve from 0.00209
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1302 - accuracy: 0.9554 - val_loss: 6.3940 - val_accuracy: 0.0021
# Epoch 51/300
# 88/93 [===========================>..] - ETA: 0s - loss: 0.1287 - accuracy: 0.9559
# Epoch 00051: val_accuracy did not improve from 0.00209
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1289 - accuracy: 0.9558 - val_loss: 6.4808 - val_accuracy: 0.0021
# Epoch 52/300
# 91/93 [============================>.] - ETA: 0s - loss: 0.1276 - accuracy: 0.9564
# Epoch 00052: val_accuracy did not improve from 0.00209
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1276 - accuracy: 0.9564 - val_loss: 6.4566 - val_accuracy: 0.0021
# Epoch 53/300
# 85/93 [==========================>...] - ETA: 0s - loss: 0.1267 - accuracy: 0.9566
# Epoch 00053: val_accuracy did not improve from 0.00209
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1266 - accuracy: 0.9568 - val_loss: 6.4586 - val_accuracy: 0.0021
# Epoch 54/300
# 92/93 [============================>.] - ETA: 0s - loss: 0.1258 - accuracy: 0.9570
# Epoch 00054: val_accuracy did not improve from 0.00209
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1258 - accuracy: 0.9571 - val_loss: 6.3314 - val_accuracy: 0.0021
# Epoch 55/300
# 89/93 [===========================>..] - ETA: 0s - loss: 0.1247 - accuracy: 0.9569
# Epoch 00055: val_accuracy did not improve from 0.00209
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1248 - accuracy: 0.9568 - val_loss: 6.2624 - val_accuracy: 0.0021
# Epoch 56/300
# 86/93 [==========================>...] - ETA: 0s - loss: 0.1239 - accuracy: 0.9578
# Epoch 00056: val_accuracy did not improve from 0.00209
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1238 - accuracy: 0.9579 - val_loss: 6.3608 - val_accuracy: 0.0021
# Epoch 57/300
# 87/93 [===========================>..] - ETA: 0s - loss: 0.1238 - accuracy: 0.9573
# Epoch 00057: val_accuracy did not improve from 0.00209
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1237 - accuracy: 0.9574 - val_loss: 6.5097 - val_accuracy: 0.0021
# Epoch 58/300
# 86/93 [==========================>...] - ETA: 0s - loss: 0.1226 - accuracy: 0.9583
# Epoch 00058: val_accuracy did not improve from 0.00209
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1223 - accuracy: 0.9585 - val_loss: 6.4376 - val_accuracy: 0.0021
# Epoch 59/300
# 86/93 [==========================>...] - ETA: 0s - loss: 0.1216 - accuracy: 0.9586
# Epoch 00059: val_accuracy did not improve from 0.00209
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1215 - accuracy: 0.9586 - val_loss: 6.3633 - val_accuracy: 0.0021
# Epoch 60/300
# 88/93 [===========================>..] - ETA: 0s - loss: 0.1209 - accuracy: 0.9587
# Epoch 00060: val_accuracy did not improve from 0.00209
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1210 - accuracy: 0.9587 - val_loss: 6.2377 - val_accuracy: 0.0021
# Epoch 61/300
# 88/93 [===========================>..] - ETA: 0s - loss: 0.1201 - accuracy: 0.9589
# Epoch 00061: val_accuracy did not improve from 0.00209
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1202 - accuracy: 0.9589 - val_loss: 6.3382 - val_accuracy: 0.0021
# Epoch 62/300
# 85/93 [==========================>...] - ETA: 0s - loss: 0.1194 - accuracy: 0.9594
# Epoch 00062: val_accuracy did not improve from 0.00209
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1197 - accuracy: 0.9594 - val_loss: 6.3996 - val_accuracy: 0.0021
# Epoch 63/300
# 87/93 [===========================>..] - ETA: 0s - loss: 0.1188 - accuracy: 0.9596
# Epoch 00063: val_accuracy did not improve from 0.00209
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1189 - accuracy: 0.9596 - val_loss: 6.2377 - val_accuracy: 0.0021
# Epoch 64/300
# 90/93 [============================>.] - ETA: 0s - loss: 0.1180 - accuracy: 0.9598
# Epoch 00064: val_accuracy did not improve from 0.00209
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1180 - accuracy: 0.9598 - val_loss: 6.2797 - val_accuracy: 0.0021
# Epoch 65/300
# 86/93 [==========================>...] - ETA: 0s - loss: 0.1173 - accuracy: 0.9600
# Epoch 00065: val_accuracy did not improve from 0.00209
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1175 - accuracy: 0.9599 - val_loss: 6.2327 - val_accuracy: 0.0021
# Epoch 66/300
# 90/93 [============================>.] - ETA: 0s - loss: 0.1176 - accuracy: 0.9597
# Epoch 00066: val_accuracy did not improve from 0.00209
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1175 - accuracy: 0.9598 - val_loss: 6.2270 - val_accuracy: 0.0021
# Epoch 67/300
# 87/93 [===========================>..] - ETA: 0s - loss: 0.1158 - accuracy: 0.9603
# Epoch 00067: val_accuracy did not improve from 0.00209
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1160 - accuracy: 0.9602 - val_loss: 6.2771 - val_accuracy: 0.0021
# Epoch 68/300
# 86/93 [==========================>...] - ETA: 0s - loss: 0.1152 - accuracy: 0.9609
# Epoch 00068: val_accuracy did not improve from 0.00209
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1154 - accuracy: 0.9607 - val_loss: 6.0542 - val_accuracy: 0.0021
# Epoch 69/300
# 90/93 [============================>.] - ETA: 0s - loss: 0.1154 - accuracy: 0.9608
# Epoch 00069: val_accuracy did not improve from 0.00209
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1153 - accuracy: 0.9609 - val_loss: 6.2327 - val_accuracy: 0.0021
# Epoch 70/300
# 88/93 [===========================>..] - ETA: 0s - loss: 0.1138 - accuracy: 0.9612
# Epoch 00070: val_accuracy did not improve from 0.00209
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1137 - accuracy: 0.9612 - val_loss: 6.0829 - val_accuracy: 0.0021
# Epoch 71/300
# 93/93 [==============================] - ETA: 0s - loss: 0.1132 - accuracy: 0.9617
# Epoch 00071: val_accuracy did not improve from 0.00209
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1132 - accuracy: 0.9617 - val_loss: 6.1330 - val_accuracy: 0.0021
# Epoch 72/300
# 88/93 [===========================>..] - ETA: 0s - loss: 0.1131 - accuracy: 0.9616
# Epoch 00072: val_accuracy did not improve from 0.00209
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1131 - accuracy: 0.9615 - val_loss: 6.0436 - val_accuracy: 0.0021
# Epoch 73/300
# 84/93 [==========================>...] - ETA: 0s - loss: 0.1128 - accuracy: 0.9619
# Epoch 00073: val_accuracy did not improve from 0.00209
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1124 - accuracy: 0.9620 - val_loss: 6.1250 - val_accuracy: 0.0021
# Epoch 74/300
# 89/93 [===========================>..] - ETA: 0s - loss: 0.1122 - accuracy: 0.9617
# Epoch 00074: val_accuracy did not improve from 0.00209
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1120 - accuracy: 0.9616 - val_loss: 6.0972 - val_accuracy: 0.0021
# Epoch 75/300
# 89/93 [===========================>..] - ETA: 0s - loss: 0.1120 - accuracy: 0.9618
# Epoch 00075: val_accuracy did not improve from 0.00209
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1121 - accuracy: 0.9618 - val_loss: 6.0931 - val_accuracy: 0.0021
# Epoch 76/300
# 84/93 [==========================>...] - ETA: 0s - loss: 0.1103 - accuracy: 0.9627
# Epoch 00076: val_accuracy did not improve from 0.00209
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1104 - accuracy: 0.9628 - val_loss: 6.0435 - val_accuracy: 0.0021
# Epoch 77/300
# 90/93 [============================>.] - ETA: 0s - loss: 0.1099 - accuracy: 0.9630
# Epoch 00077: val_accuracy did not improve from 0.00209
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1099 - accuracy: 0.9630 - val_loss: 6.0908 - val_accuracy: 0.0021
# Epoch 78/300
# 90/93 [============================>.] - ETA: 0s - loss: 0.1091 - accuracy: 0.9630
# Epoch 00078: val_accuracy did not improve from 0.00209
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1093 - accuracy: 0.9630 - val_loss: 6.0858 - val_accuracy: 0.0021
# Epoch 79/300
# 92/93 [============================>.] - ETA: 0s - loss: 0.1093 - accuracy: 0.9631
# Epoch 00079: val_accuracy did not improve from 0.00209
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1093 - accuracy: 0.9631 - val_loss: 5.8295 - val_accuracy: 0.0021
# Epoch 80/300
# 89/93 [===========================>..] - ETA: 0s - loss: 0.1083 - accuracy: 0.9632
# Epoch 00080: val_accuracy did not improve from 0.00209
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1087 - accuracy: 0.9631 - val_loss: 5.9853 - val_accuracy: 0.0021
# Epoch 81/300
# 88/93 [===========================>..] - ETA: 0s - loss: 0.1083 - accuracy: 0.9631
# Epoch 00081: val_accuracy did not improve from 0.00209
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1089 - accuracy: 0.9628 - val_loss: 6.0759 - val_accuracy: 0.0021
# Epoch 82/300
# 88/93 [===========================>..] - ETA: 0s - loss: 0.1078 - accuracy: 0.9636
# Epoch 00082: val_accuracy did not improve from 0.00209
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1081 - accuracy: 0.9634 - val_loss: 5.8544 - val_accuracy: 0.0021
# Epoch 83/300
# 91/93 [============================>.] - ETA: 0s - loss: 0.1086 - accuracy: 0.9632
# Epoch 00083: val_accuracy did not improve from 0.00209
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1087 - accuracy: 0.9631 - val_loss: 5.9512 - val_accuracy: 0.0021
# Epoch 84/300
# 86/93 [==========================>...] - ETA: 0s - loss: 0.1079 - accuracy: 0.9631
# Epoch 00084: val_accuracy did not improve from 0.00209
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1076 - accuracy: 0.9632 - val_loss: 5.9980 - val_accuracy: 0.0021
# Epoch 85/300
# 89/93 [===========================>..] - ETA: 0s - loss: 0.1073 - accuracy: 0.9638
# Epoch 00085: val_accuracy did not improve from 0.00209
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1074 - accuracy: 0.9638 - val_loss: 5.8563 - val_accuracy: 0.0021
# Epoch 86/300
# 88/93 [===========================>..] - ETA: 0s - loss: 0.1062 - accuracy: 0.9643
# Epoch 00086: val_accuracy did not improve from 0.00209
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1061 - accuracy: 0.9644 - val_loss: 5.9138 - val_accuracy: 0.0021
# Epoch 87/300
# 89/93 [===========================>..] - ETA: 0s - loss: 0.1062 - accuracy: 0.9642
# Epoch 00087: val_accuracy did not improve from 0.00209
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1062 - accuracy: 0.9642 - val_loss: 5.8347 - val_accuracy: 0.0021
# Epoch 88/300
# 90/93 [============================>.] - ETA: 0s - loss: 0.1065 - accuracy: 0.9638
# Epoch 00088: val_accuracy did not improve from 0.00209
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1064 - accuracy: 0.9639 - val_loss: 6.0571 - val_accuracy: 0.0021
# Epoch 89/300
# 89/93 [===========================>..] - ETA: 0s - loss: 0.1055 - accuracy: 0.9643
# Epoch 00089: val_accuracy did not improve from 0.00209
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1057 - accuracy: 0.9642 - val_loss: 5.8828 - val_accuracy: 0.0021
# Epoch 90/300
# 88/93 [===========================>..] - ETA: 0s - loss: 0.1049 - accuracy: 0.9647
# Epoch 00090: val_accuracy did not improve from 0.00209
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1051 - accuracy: 0.9648 - val_loss: 5.9122 - val_accuracy: 0.0021
# Epoch 91/300
# 87/93 [===========================>..] - ETA: 0s - loss: 0.1046 - accuracy: 0.9646
# Epoch 00091: val_accuracy improved from 0.00209 to 0.00270, saving model to D:\Download\zyFile\Cyberthreat_Cognitive_System\CTCS_Code\attack_datasets\NSL-KDD\Model\NSL-KDD\AUG\LSTM\Mix_dataset_One_Hot_MI_ADASYN.h5
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1044 - accuracy: 0.9647 - val_loss: 5.8571 - val_accuracy: 0.0027
# Epoch 92/300
# 89/93 [===========================>..] - ETA: 0s - loss: 0.1047 - accuracy: 0.9647
# Epoch 00092: val_accuracy did not improve from 0.00270
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1043 - accuracy: 0.9648 - val_loss: 5.8527 - val_accuracy: 0.0021
# Epoch 93/300
# 90/93 [============================>.] - ETA: 0s - loss: 0.1035 - accuracy: 0.9651
# Epoch 00093: val_accuracy did not improve from 0.00270
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1037 - accuracy: 0.9650 - val_loss: 5.8824 - val_accuracy: 0.0021
# Epoch 94/300
# 87/93 [===========================>..] - ETA: 0s - loss: 0.1033 - accuracy: 0.9652
# Epoch 00094: val_accuracy did not improve from 0.00270
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1031 - accuracy: 0.9653 - val_loss: 5.8916 - val_accuracy: 0.0021
# Epoch 95/300
# 86/93 [==========================>...] - ETA: 0s - loss: 0.1035 - accuracy: 0.9649
# Epoch 00095: val_accuracy did not improve from 0.00270
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1034 - accuracy: 0.9650 - val_loss: 5.7967 - val_accuracy: 0.0022
# Epoch 96/300
# 92/93 [============================>.] - ETA: 0s - loss: 0.1029 - accuracy: 0.9656
# Epoch 00096: val_accuracy did not improve from 0.00270
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1029 - accuracy: 0.9656 - val_loss: 5.7655 - val_accuracy: 0.0021
# Epoch 97/300
# 92/93 [============================>.] - ETA: 0s - loss: 0.1024 - accuracy: 0.9653
# Epoch 00097: val_accuracy did not improve from 0.00270
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1024 - accuracy: 0.9654 - val_loss: 5.7355 - val_accuracy: 0.0022
# Epoch 98/300
# 89/93 [===========================>..] - ETA: 0s - loss: 0.1019 - accuracy: 0.9659
# Epoch 00098: val_accuracy did not improve from 0.00270
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1018 - accuracy: 0.9660 - val_loss: 5.6777 - val_accuracy: 0.0025
# Epoch 99/300
# 93/93 [==============================] - ETA: 0s - loss: 0.1019 - accuracy: 0.9661
# Epoch 00099: val_accuracy did not improve from 0.00270
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1019 - accuracy: 0.9661 - val_loss: 5.7321 - val_accuracy: 0.0027
# Epoch 100/300
# 89/93 [===========================>..] - ETA: 0s - loss: 0.1012 - accuracy: 0.9659
# Epoch 00100: val_accuracy did not improve from 0.00270
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1013 - accuracy: 0.9659 - val_loss: 5.8754 - val_accuracy: 0.0021
# Epoch 101/300
# 88/93 [===========================>..] - ETA: 0s - loss: 0.1014 - accuracy: 0.9656
# Epoch 00101: val_accuracy did not improve from 0.00270
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1015 - accuracy: 0.9657 - val_loss: 5.7951 - val_accuracy: 0.0024
# Epoch 102/300
# 93/93 [==============================] - ETA: 0s - loss: 0.1005 - accuracy: 0.9665
# Epoch 00102: val_accuracy did not improve from 0.00270
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1005 - accuracy: 0.9665 - val_loss: 5.7404 - val_accuracy: 0.0021
# Epoch 103/300
# 92/93 [============================>.] - ETA: 0s - loss: 0.1008 - accuracy: 0.9663
# Epoch 00103: val_accuracy did not improve from 0.00270
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1008 - accuracy: 0.9663 - val_loss: 5.6073 - val_accuracy: 0.0023
# Epoch 104/300
# 86/93 [==========================>...] - ETA: 0s - loss: 0.0991 - accuracy: 0.9668
# Epoch 00104: val_accuracy did not improve from 0.00270
# 93/93 [==============================] - 1s 6ms/step - loss: 0.0992 - accuracy: 0.9667 - val_loss: 5.5737 - val_accuracy: 0.0021
# Epoch 105/300
# 91/93 [============================>.] - ETA: 0s - loss: 0.1001 - accuracy: 0.9667
# Epoch 00105: val_accuracy did not improve from 0.00270
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1000 - accuracy: 0.9668 - val_loss: 5.6315 - val_accuracy: 0.0021
# Epoch 106/300
# 85/93 [==========================>...] - ETA: 0s - loss: 0.0996 - accuracy: 0.9664
# Epoch 00106: val_accuracy did not improve from 0.00270
# 93/93 [==============================] - 1s 6ms/step - loss: 0.0992 - accuracy: 0.9665 - val_loss: 5.6734 - val_accuracy: 0.0021
# Epoch 107/300
# 91/93 [============================>.] - ETA: 0s - loss: 0.0991 - accuracy: 0.9669
# Epoch 00107: val_accuracy did not improve from 0.00270
# 93/93 [==============================] - 1s 6ms/step - loss: 0.0991 - accuracy: 0.9670 - val_loss: 5.6194 - val_accuracy: 0.0021
# Epoch 108/300
# 88/93 [===========================>..] - ETA: 0s - loss: 0.0979 - accuracy: 0.9672
# Epoch 00108: val_accuracy did not improve from 0.00270
# 93/93 [==============================] - 1s 6ms/step - loss: 0.0982 - accuracy: 0.9670 - val_loss: 5.6047 - val_accuracy: 0.0021
# Epoch 109/300
# 84/93 [==========================>...] - ETA: 0s - loss: 0.0986 - accuracy: 0.9673
# Epoch 00109: val_accuracy did not improve from 0.00270
# 93/93 [==============================] - 1s 6ms/step - loss: 0.0984 - accuracy: 0.9673 - val_loss: 5.8697 - val_accuracy: 0.0021
# Epoch 110/300
# 89/93 [===========================>..] - ETA: 0s - loss: 0.0982 - accuracy: 0.9667
# Epoch 00110: val_accuracy improved from 0.00270 to 0.00277, saving model to D:\Download\zyFile\Cyberthreat_Cognitive_System\CTCS_Code\attack_datasets\NSL-KDD\Model\NSL-KDD\AUG\LSTM\Mix_dataset_One_Hot_MI_ADASYN.h5
# 93/93 [==============================] - 1s 6ms/step - loss: 0.0982 - accuracy: 0.9666 - val_loss: 5.5917 - val_accuracy: 0.0028
# Epoch 111/300
# 91/93 [============================>.] - ETA: 0s - loss: 0.0981 - accuracy: 0.9668
# Epoch 00111: val_accuracy improved from 0.00277 to 0.00388, saving model to D:\Download\zyFile\Cyberthreat_Cognitive_System\CTCS_Code\attack_datasets\NSL-KDD\Model\NSL-KDD\AUG\LSTM\Mix_dataset_One_Hot_MI_ADASYN.h5
# 93/93 [==============================] - 1s 6ms/step - loss: 0.0980 - accuracy: 0.9668 - val_loss: 5.6780 - val_accuracy: 0.0039
# Epoch 112/300
# 92/93 [============================>.] - ETA: 0s - loss: 0.0978 - accuracy: 0.9676
# Epoch 00112: val_accuracy did not improve from 0.00388
# 93/93 [==============================] - 1s 6ms/step - loss: 0.0977 - accuracy: 0.9676 - val_loss: 5.7966 - val_accuracy: 0.0033
# Epoch 113/300
# 91/93 [============================>.] - ETA: 0s - loss: 0.0966 - accuracy: 0.9677
# Epoch 00113: val_accuracy improved from 0.00388 to 0.00438, saving model to D:\Download\zyFile\Cyberthreat_Cognitive_System\CTCS_Code\attack_datasets\NSL-KDD\Model\NSL-KDD\AUG\LSTM\Mix_dataset_One_Hot_MI_ADASYN.h5
# 93/93 [==============================] - 1s 6ms/step - loss: 0.0966 - accuracy: 0.9676 - val_loss: 5.6330 - val_accuracy: 0.0044
# Epoch 114/300
# 90/93 [============================>.] - ETA: 0s - loss: 0.0965 - accuracy: 0.9676
# Epoch 00114: val_accuracy improved from 0.00438 to 0.00547, saving model to D:\Download\zyFile\Cyberthreat_Cognitive_System\CTCS_Code\attack_datasets\NSL-KDD\Model\NSL-KDD\AUG\LSTM\Mix_dataset_One_Hot_MI_ADASYN.h5
# 93/93 [==============================] - 1s 6ms/step - loss: 0.0964 - accuracy: 0.9677 - val_loss: 5.6317 - val_accuracy: 0.0055
# Epoch 115/300
# 88/93 [===========================>..] - ETA: 0s - loss: 0.0963 - accuracy: 0.9678
# Epoch 00115: val_accuracy did not improve from 0.00547
# 93/93 [==============================] - 1s 6ms/step - loss: 0.0964 - accuracy: 0.9678 - val_loss: 5.5760 - val_accuracy: 0.0052
# Epoch 116/300
# 84/93 [==========================>...] - ETA: 0s - loss: 0.0970 - accuracy: 0.9671
# Epoch 00116: val_accuracy did not improve from 0.00547
# 93/93 [==============================] - 1s 6ms/step - loss: 0.0969 - accuracy: 0.9673 - val_loss: 5.5449 - val_accuracy: 0.0047
# Epoch 117/300
# 84/93 [==========================>...] - ETA: 0s - loss: 0.0975 - accuracy: 0.9678
# Epoch 00117: val_accuracy did not improve from 0.00547
# 93/93 [==============================] - 1s 6ms/step - loss: 0.0972 - accuracy: 0.9679 - val_loss: 5.6058 - val_accuracy: 0.0049
# Epoch 118/300
# 86/93 [==========================>...] - ETA: 0s - loss: 0.0959 - accuracy: 0.9677
# Epoch 00118: val_accuracy did not improve from 0.00547
# 93/93 [==============================] - 1s 6ms/step - loss: 0.0958 - accuracy: 0.9678 - val_loss: 5.5274 - val_accuracy: 0.0047
# Epoch 119/300
# 87/93 [===========================>..] - ETA: 0s - loss: 0.0959 - accuracy: 0.9679
# Epoch 00119: val_accuracy did not improve from 0.00547
# 93/93 [==============================] - 1s 6ms/step - loss: 0.0958 - accuracy: 0.9680 - val_loss: 5.5563 - val_accuracy: 0.0049
# Epoch 120/300
# 86/93 [==========================>...] - ETA: 0s - loss: 0.0955 - accuracy: 0.9679
# Epoch 00120: val_accuracy improved from 0.00547 to 0.00555, saving model to D:\Download\zyFile\Cyberthreat_Cognitive_System\CTCS_Code\attack_datasets\NSL-KDD\Model\NSL-KDD\AUG\LSTM\Mix_dataset_One_Hot_MI_ADASYN.h5
# 93/93 [==============================] - 1s 6ms/step - loss: 0.0956 - accuracy: 0.9679 - val_loss: 5.4206 - val_accuracy: 0.0056
# Epoch 121/300
# 87/93 [===========================>..] - ETA: 0s - loss: 0.0953 - accuracy: 0.9683
# Epoch 00121: val_accuracy improved from 0.00555 to 0.00578, saving model to D:\Download\zyFile\Cyberthreat_Cognitive_System\CTCS_Code\attack_datasets\NSL-KDD\Model\NSL-KDD\AUG\LSTM\Mix_dataset_One_Hot_MI_ADASYN.h5
# 93/93 [==============================] - 1s 6ms/step - loss: 0.0951 - accuracy: 0.9683 - val_loss: 5.6433 - val_accuracy: 0.0058
# Epoch 122/300
# 89/93 [===========================>..] - ETA: 0s - loss: 0.0955 - accuracy: 0.9684
# Epoch 00122: val_accuracy did not improve from 0.00578
# 93/93 [==============================] - 1s 6ms/step - loss: 0.0955 - accuracy: 0.9684 - val_loss: 5.4428 - val_accuracy: 0.0057
# Epoch 123/300
# 91/93 [============================>.] - ETA: 0s - loss: 0.0949 - accuracy: 0.9684
# Epoch 00123: val_accuracy did not improve from 0.00578
# 93/93 [==============================] - 1s 6ms/step - loss: 0.0951 - accuracy: 0.9683 - val_loss: 5.4360 - val_accuracy: 0.0038
# Epoch 124/300
# 90/93 [============================>.] - ETA: 0s - loss: 0.0949 - accuracy: 0.9682
# Epoch 00124: val_accuracy did not improve from 0.00578
# 93/93 [==============================] - 1s 6ms/step - loss: 0.0947 - accuracy: 0.9683 - val_loss: 5.5015 - val_accuracy: 0.0035
# Epoch 125/300
# 93/93 [==============================] - ETA: 0s - loss: 0.0949 - accuracy: 0.9685
# Epoch 00125: val_accuracy did not improve from 0.00578
# 93/93 [==============================] - 1s 6ms/step - loss: 0.0949 - accuracy: 0.9685 - val_loss: 5.5525 - val_accuracy: 0.0038
# Epoch 126/300
# 88/93 [===========================>..] - ETA: 0s - loss: 0.0947 - accuracy: 0.9684
# Epoch 00126: val_accuracy did not improve from 0.00578
# 93/93 [==============================] - 1s 6ms/step - loss: 0.0946 - accuracy: 0.9684 - val_loss: 5.5229 - val_accuracy: 0.0038
# Epoch 127/300
# 91/93 [============================>.] - ETA: 0s - loss: 0.0937 - accuracy: 0.9688
# Epoch 00127: val_accuracy did not improve from 0.00578
# 93/93 [==============================] - 1s 6ms/step - loss: 0.0939 - accuracy: 0.9688 - val_loss: 5.4404 - val_accuracy: 0.0038
# Epoch 128/300
# 91/93 [============================>.] - ETA: 0s - loss: 0.0931 - accuracy: 0.9689
# Epoch 00128: val_accuracy did not improve from 0.00578
# 93/93 [==============================] - 1s 6ms/step - loss: 0.0931 - accuracy: 0.9689 - val_loss: 5.4020 - val_accuracy: 0.0021
# Epoch 129/300
# 93/93 [==============================] - ETA: 0s - loss: 0.0939 - accuracy: 0.9685
# Epoch 00129: val_accuracy did not improve from 0.00578
# 93/93 [==============================] - 1s 6ms/step - loss: 0.0939 - accuracy: 0.9685 - val_loss: 5.5326 - val_accuracy: 0.0035
# Epoch 130/300
# 87/93 [===========================>..] - ETA: 0s - loss: 0.0931 - accuracy: 0.9688
# Epoch 00130: val_accuracy did not improve from 0.00578
# 93/93 [==============================] - 1s 6ms/step - loss: 0.0929 - accuracy: 0.9689 - val_loss: 5.5128 - val_accuracy: 0.0036
# Epoch 131/300
# 91/93 [============================>.] - ETA: 0s - loss: 0.0930 - accuracy: 0.9694
# Epoch 00131: val_accuracy did not improve from 0.00578
# 93/93 [==============================] - 1s 6ms/step - loss: 0.0931 - accuracy: 0.9694 - val_loss: 5.5490 - val_accuracy: 0.0047
# Epoch 132/300
# 83/93 [=========================>....] - ETA: 0s - loss: 0.0929 - accuracy: 0.9691
# Epoch 00132: val_accuracy did not improve from 0.00578
# 93/93 [==============================] - 1s 6ms/step - loss: 0.0928 - accuracy: 0.9691 - val_loss: 5.5368 - val_accuracy: 0.0041
# Epoch 133/300
# 88/93 [===========================>..] - ETA: 0s - loss: 0.0930 - accuracy: 0.9690
# Epoch 00133: val_accuracy did not improve from 0.00578
# 93/93 [==============================] - 1s 6ms/step - loss: 0.0931 - accuracy: 0.9690 - val_loss: 5.4350 - val_accuracy: 0.0041
# Epoch 134/300
# 93/93 [==============================] - ETA: 0s - loss: 0.0930 - accuracy: 0.9691
# Epoch 00134: val_accuracy did not improve from 0.00578
# 93/93 [==============================] - 1s 6ms/step - loss: 0.0930 - accuracy: 0.9691 - val_loss: 5.3738 - val_accuracy: 0.0037
# Epoch 135/300
# 90/93 [============================>.] - ETA: 0s - loss: 0.0919 - accuracy: 0.9696
# Epoch 00135: val_accuracy did not improve from 0.00578
# 93/93 [==============================] - 1s 6ms/step - loss: 0.0919 - accuracy: 0.9696 - val_loss: 5.3909 - val_accuracy: 0.0021
# Epoch 136/300
# 83/93 [=========================>....] - ETA: 0s - loss: 0.0921 - accuracy: 0.9697
# Epoch 00136: val_accuracy did not improve from 0.00578
# 93/93 [==============================] - 1s 6ms/step - loss: 0.0924 - accuracy: 0.9697 - val_loss: 5.4688 - val_accuracy: 0.0030
# Epoch 137/300
# 90/93 [============================>.] - ETA: 0s - loss: 0.0912 - accuracy: 0.9696
# Epoch 00137: val_accuracy did not improve from 0.00578
# 93/93 [==============================] - 1s 6ms/step - loss: 0.0913 - accuracy: 0.9696 - val_loss: 5.3299 - val_accuracy: 0.0021
# Epoch 138/300
# 87/93 [===========================>..] - ETA: 0s - loss: 0.0917 - accuracy: 0.9700
# Epoch 00138: val_accuracy did not improve from 0.00578
# 93/93 [==============================] - 1s 6ms/step - loss: 0.0916 - accuracy: 0.9700 - val_loss: 5.4129 - val_accuracy: 0.0037
# Epoch 139/300
# 92/93 [============================>.] - ETA: 0s - loss: 0.0904 - accuracy: 0.9701
# Epoch 00139: val_accuracy did not improve from 0.00578
# 93/93 [==============================] - 1s 6ms/step - loss: 0.0904 - accuracy: 0.9701 - val_loss: 5.3790 - val_accuracy: 0.0026
# Epoch 140/300
# 83/93 [=========================>....] - ETA: 0s - loss: 0.0903 - accuracy: 0.9700
# Epoch 00140: val_accuracy did not improve from 0.00578
# 93/93 [==============================] - 1s 6ms/step - loss: 0.0907 - accuracy: 0.9699 - val_loss: 5.3767 - val_accuracy: 0.0021
# Epoch 141/300
# 86/93 [==========================>...] - ETA: 0s - loss: 0.0912 - accuracy: 0.9697
# Epoch 00141: val_accuracy did not improve from 0.00578
# 93/93 [==============================] - 1s 6ms/step - loss: 0.0911 - accuracy: 0.9696 - val_loss: 5.1821 - val_accuracy: 0.0042
# Epoch 142/300
# 90/93 [============================>.] - ETA: 0s - loss: 0.0908 - accuracy: 0.9698
# Epoch 00142: val_accuracy did not improve from 0.00578
# 93/93 [==============================] - 1s 6ms/step - loss: 0.0906 - accuracy: 0.9699 - val_loss: 5.3156 - val_accuracy: 0.0048
# Epoch 143/300
# 88/93 [===========================>..] - ETA: 0s - loss: 0.0906 - accuracy: 0.9702
# Epoch 00143: val_accuracy did not improve from 0.00578
# 93/93 [==============================] - 1s 6ms/step - loss: 0.0908 - accuracy: 0.9701 - val_loss: 5.2808 - val_accuracy: 0.0042
# Epoch 144/300
# 91/93 [============================>.] - ETA: 0s - loss: 0.0897 - accuracy: 0.9704
# Epoch 00144: val_accuracy did not improve from 0.00578
# 93/93 [==============================] - 1s 6ms/step - loss: 0.0898 - accuracy: 0.9704 - val_loss: 5.2301 - val_accuracy: 0.0045
# Epoch 145/300
# 89/93 [===========================>..] - ETA: 0s - loss: 0.0901 - accuracy: 0.9702
# Epoch 00145: val_accuracy did not improve from 0.00578
# 93/93 [==============================] - 1s 6ms/step - loss: 0.0903 - accuracy: 0.9701 - val_loss: 5.3221 - val_accuracy: 0.0051
# Epoch 146/300
# 89/93 [===========================>..] - ETA: 0s - loss: 0.0901 - accuracy: 0.9702
# Epoch 00146: val_accuracy did not improve from 0.00578
# 93/93 [==============================] - 1s 6ms/step - loss: 0.0900 - accuracy: 0.9702 - val_loss: 5.3509 - val_accuracy: 0.0054
# Epoch 147/300
# 90/93 [============================>.] - ETA: 0s - loss: 0.0888 - accuracy: 0.9706
# Epoch 00147: val_accuracy did not improve from 0.00578
# 93/93 [==============================] - 1s 6ms/step - loss: 0.0889 - accuracy: 0.9706 - val_loss: 5.2225 - val_accuracy: 0.0050
# Epoch 148/300
# 92/93 [============================>.] - ETA: 0s - loss: 0.0898 - accuracy: 0.9706
# Epoch 00148: val_accuracy improved from 0.00578 to 0.00588, saving model to D:\Download\zyFile\Cyberthreat_Cognitive_System\CTCS_Code\attack_datasets\NSL-KDD\Model\NSL-KDD\AUG\LSTM\Mix_dataset_One_Hot_MI_ADASYN.h5
# 93/93 [==============================] - 1s 6ms/step - loss: 0.0900 - accuracy: 0.9706 - val_loss: 5.2027 - val_accuracy: 0.0059
# Epoch 149/300
# 84/93 [==========================>...] - ETA: 0s - loss: 0.0897 - accuracy: 0.9703
# Epoch 00149: val_accuracy improved from 0.00588 to 0.00844, saving model to D:\Download\zyFile\Cyberthreat_Cognitive_System\CTCS_Code\attack_datasets\NSL-KDD\Model\NSL-KDD\AUG\LSTM\Mix_dataset_One_Hot_MI_ADASYN.h5
# 93/93 [==============================] - 1s 6ms/step - loss: 0.0893 - accuracy: 0.9705 - val_loss: 5.2133 - val_accuracy: 0.0084
# Epoch 150/300
# 87/93 [===========================>..] - ETA: 0s - loss: 0.0892 - accuracy: 0.9705
# Epoch 00150: val_accuracy did not improve from 0.00844
# 93/93 [==============================] - 1s 6ms/step - loss: 0.0889 - accuracy: 0.9705 - val_loss: 5.3503 - val_accuracy: 0.0056
# Epoch 151/300
# 91/93 [============================>.] - ETA: 0s - loss: 0.0893 - accuracy: 0.9704
# Epoch 00151: val_accuracy did not improve from 0.00844
# 93/93 [==============================] - 1s 6ms/step - loss: 0.0895 - accuracy: 0.9704 - val_loss: 5.3327 - val_accuracy: 0.0052
# Epoch 152/300
# 84/93 [==========================>...] - ETA: 0s - loss: 0.0883 - accuracy: 0.9712
# Epoch 00152: val_accuracy did not improve from 0.00844
# 93/93 [==============================] - 1s 6ms/step - loss: 0.0885 - accuracy: 0.9709 - val_loss: 5.4327 - val_accuracy: 0.0069
# Epoch 153/300
# 84/93 [==========================>...] - ETA: 0s - loss: 0.0880 - accuracy: 0.9708
# Epoch 00153: val_accuracy did not improve from 0.00844
# 93/93 [==============================] - 1s 6ms/step - loss: 0.0881 - accuracy: 0.9708 - val_loss: 5.2650 - val_accuracy: 0.0060
# Epoch 154/300
# 87/93 [===========================>..] - ETA: 0s - loss: 0.0880 - accuracy: 0.9710
# Epoch 00154: val_accuracy did not improve from 0.00844
# 93/93 [==============================] - 1s 6ms/step - loss: 0.0882 - accuracy: 0.9710 - val_loss: 5.1766 - val_accuracy: 0.0057
# Epoch 155/300
# 88/93 [===========================>..] - ETA: 0s - loss: 0.0883 - accuracy: 0.9709
# Epoch 00155: val_accuracy did not improve from 0.00844
# 93/93 [==============================] - 1s 6ms/step - loss: 0.0882 - accuracy: 0.9710 - val_loss: 5.2912 - val_accuracy: 0.0067
# Epoch 156/300
# 88/93 [===========================>..] - ETA: 0s - loss: 0.0872 - accuracy: 0.9713
# Epoch 00156: val_accuracy did not improve from 0.00844
# 93/93 [==============================] - 1s 6ms/step - loss: 0.0872 - accuracy: 0.9712 - val_loss: 5.1400 - val_accuracy: 0.0069
# Epoch 157/300
# 92/93 [============================>.] - ETA: 0s - loss: 0.0868 - accuracy: 0.9715
# Epoch 00157: val_accuracy improved from 0.00844 to 0.00901, saving model to D:\Download\zyFile\Cyberthreat_Cognitive_System\CTCS_Code\attack_datasets\NSL-KDD\Model\NSL-KDD\AUG\LSTM\Mix_dataset_One_Hot_MI_ADASYN.h5
# 93/93 [==============================] - 1s 7ms/step - loss: 0.0867 - accuracy: 0.9715 - val_loss: 5.2372 - val_accuracy: 0.0090
# Epoch 158/300
# 91/93 [============================>.] - ETA: 0s - loss: 0.0869 - accuracy: 0.9716
# Epoch 00158: val_accuracy did not improve from 0.00901
# 93/93 [==============================] - 1s 6ms/step - loss: 0.0871 - accuracy: 0.9715 - val_loss: 5.2869 - val_accuracy: 0.0061
# Epoch 159/300
# 87/93 [===========================>..] - ETA: 0s - loss: 0.0882 - accuracy: 0.9711
# Epoch 00159: val_accuracy did not improve from 0.00901
# 93/93 [==============================] - 1s 6ms/step - loss: 0.0882 - accuracy: 0.9711 - val_loss: 5.2214 - val_accuracy: 0.0084
# Epoch 160/300
# 85/93 [==========================>...] - ETA: 0s - loss: 0.0868 - accuracy: 0.9712
# Epoch 00160: val_accuracy did not improve from 0.00901
# 93/93 [==============================] - 1s 6ms/step - loss: 0.0872 - accuracy: 0.9711 - val_loss: 5.2341 - val_accuracy: 0.0060
# Epoch 161/300
# 90/93 [============================>.] - ETA: 0s - loss: 0.0877 - accuracy: 0.9712
# Epoch 00161: val_accuracy did not improve from 0.00901
# 93/93 [==============================] - 1s 6ms/step - loss: 0.0872 - accuracy: 0.9713 - val_loss: 5.2705 - val_accuracy: 0.0059
# Epoch 162/300
# 88/93 [===========================>..] - ETA: 0s - loss: 0.0864 - accuracy: 0.9713
# Epoch 00162: val_accuracy did not improve from 0.00901
# 93/93 [==============================] - 1s 6ms/step - loss: 0.0864 - accuracy: 0.9714 - val_loss: 5.2486 - val_accuracy: 0.0085
# Epoch 163/300
# 91/93 [============================>.] - ETA: 0s - loss: 0.0871 - accuracy: 0.9711
# Epoch 00163: val_accuracy did not improve from 0.00901
# 93/93 [==============================] - 1s 6ms/step - loss: 0.0872 - accuracy: 0.9711 - val_loss: 5.1702 - val_accuracy: 0.0075
# Epoch 164/300
# 87/93 [===========================>..] - ETA: 0s - loss: 0.0866 - accuracy: 0.9714
# Epoch 00164: val_accuracy improved from 0.00901 to 0.00931, saving model to D:\Download\zyFile\Cyberthreat_Cognitive_System\CTCS_Code\attack_datasets\NSL-KDD\Model\NSL-KDD\AUG\LSTM\Mix_dataset_One_Hot_MI_ADASYN.h5
# 93/93 [==============================] - 1s 6ms/step - loss: 0.0868 - accuracy: 0.9713 - val_loss: 5.2286 - val_accuracy: 0.0093
# Epoch 165/300
# 86/93 [==========================>...] - ETA: 0s - loss: 0.0860 - accuracy: 0.9714
# ...
# Epoch 247/300
# 90/93 [============================>.] - ETA: 0s - loss: 0.0759 - accuracy: 0.9757
# Epoch 00247: val_accuracy did not improve from 0.01247
# 93/93 [==============================] - 1s 6ms/step - loss: 0.0761 - accuracy: 0.9756 - val_loss: 4.8427 - val_accuracy: 0.0115
# Epoch 248/300
# 88/93 [===========================>..] - ETA: 0s - loss: 0.0754 - accuracy: 0.9755
# Epoch 00248: val_accuracy did not improve from 0.01247
# 93/93 [==============================] - 1s 6ms/step - loss: 0.0753 - accuracy: 0.9756 - val_loss: 4.8553 - val_accuracy: 0.0109
# Epoch 249/300
# 85/93 [==========================>...] - ETA: 0s - loss: 0.0747 - accuracy: 0.9754
# Epoch 00249: val_accuracy did not improve from 0.01247
# 93/93 [==============================] - 1s 6ms/step - loss: 0.0748 - accuracy: 0.9754 - val_loss: 4.8182 - val_accuracy: 0.0119
# Epoch 250/300
# 93/93 [==============================] - ETA: 0s - loss: 0.0760 - accuracy: 0.9752
# Epoch 00250: val_accuracy did not improve from 0.01247
# 93/93 [==============================] - 1s 6ms/step - loss: 0.0760 - accuracy: 0.9752 - val_loss: 4.8186 - val_accuracy: 0.0100
# Epoch 251/300
# 89/93 [===========================>..] - ETA: 0s - loss: 0.0746 - accuracy: 0.9758
# Epoch 00251: val_accuracy did not improve from 0.01247
# 93/93 [==============================] - 1s 6ms/step - loss: 0.0744 - accuracy: 0.9758 - val_loss: 4.8681 - val_accuracy: 0.0106
# Epoch 252/300
# 91/93 [============================>.] - ETA: 0s - loss: 0.0758 - accuracy: 0.9755
# Epoch 00252: val_accuracy did not improve from 0.01247
# 93/93 [==============================] - 1s 6ms/step - loss: 0.0758 - accuracy: 0.9755 - val_loss: 4.8246 - val_accuracy: 0.0093
# Epoch 253/300
# 91/93 [============================>.] - ETA: 0s - loss: 0.0750 - accuracy: 0.9755
# Epoch 00253: val_accuracy did not improve from 0.01247
# 93/93 [==============================] - 1s 6ms/step - loss: 0.0750 - accuracy: 0.9755 - val_loss: 4.8538 - val_accuracy: 0.0098
# Epoch 254/300
# 86/93 [==========================>...] - ETA: 0s - loss: 0.0760 - accuracy: 0.9751
# Epoch 00254: val_accuracy did not improve from 0.01247
# 93/93 [==============================] - 1s 6ms/step - loss: 0.0756 - accuracy: 0.9753 - val_loss: 4.8588 - val_accuracy: 0.0090
# Epoch 255/300
# 88/93 [===========================>..] - ETA: 0s - loss: 0.0755 - accuracy: 0.9756
# Epoch 00255: val_accuracy did not improve from 0.01247
# 93/93 [==============================] - 1s 6ms/step - loss: 0.0756 - accuracy: 0.9755 - val_loss: 4.7648 - val_accuracy: 0.0107
# Epoch 256/300
# 85/93 [==========================>...] - ETA: 0s - loss: 0.0749 - accuracy: 0.9756
# Epoch 00256: val_accuracy did not improve from 0.01247
# 93/93 [==============================] - 1s 6ms/step - loss: 0.0754 - accuracy: 0.9754 - val_loss: 4.8170 - val_accuracy: 0.0100
# Epoch 257/300
# 92/93 [============================>.] - ETA: 0s - loss: 0.0747 - accuracy: 0.9758
# Epoch 00257: val_accuracy did not improve from 0.01247
# 93/93 [==============================] - 1s 6ms/step - loss: 0.0746 - accuracy: 0.9758 - val_loss: 4.8969 - val_accuracy: 0.0109
# Epoch 258/300
# 90/93 [============================>.] - ETA: 0s - loss: 0.0748 - accuracy: 0.9756
# Epoch 00258: val_accuracy did not improve from 0.01247
# 93/93 [==============================] - 1s 6ms/step - loss: 0.0748 - accuracy: 0.9755 - val_loss: 4.8986 - val_accuracy: 0.0101
# Epoch 259/300
# 88/93 [===========================>..] - ETA: 0s - loss: 0.0741 - accuracy: 0.9758
# Epoch 00259: val_accuracy did not improve from 0.01247
# 93/93 [==============================] - 1s 6ms/step - loss: 0.0741 - accuracy: 0.9758 - val_loss: 4.7228 - val_accuracy: 0.0109
# Epoch 260/300
# 89/93 [===========================>..] - ETA: 0s - loss: 0.0746 - accuracy: 0.9759
# Epoch 00260: val_accuracy did not improve from 0.01247
# 93/93 [==============================] - 1s 6ms/step - loss: 0.0745 - accuracy: 0.9759 - val_loss: 4.9199 - val_accuracy: 0.0116
# Epoch 261/300
# 87/93 [===========================>..] - ETA: 0s - loss: 0.0751 - accuracy: 0.9754
# Epoch 00261: val_accuracy improved from 0.01247 to 0.01362, saving model to D:\Download\zyFile\Cyberthreat_Cognitive_System\CTCS_Code\attack_datasets\NSL-KDD\Model\NSL-KDD\AUG\LSTM\Mix_dataset_One_Hot_MI_ADASYN.h5
# 93/93 [==============================] - 1s 7ms/step - loss: 0.0749 - accuracy: 0.9754 - val_loss: 4.6966 - val_accuracy: 0.0136
# Epoch 262/300
# 89/93 [===========================>..] - ETA: 0s - loss: 0.0736 - accuracy: 0.9760
# Epoch 00262: val_accuracy did not improve from 0.01362
# 93/93 [==============================] - 1s 6ms/step - loss: 0.0738 - accuracy: 0.9759 - val_loss: 4.7644 - val_accuracy: 0.0125
# Epoch 263/300
# 93/93 [==============================] - ETA: 0s - loss: 0.0744 - accuracy: 0.9761
# Epoch 00263: val_accuracy did not improve from 0.01362
# 93/93 [==============================] - 1s 6ms/step - loss: 0.0744 - accuracy: 0.9761 - val_loss: 4.8298 - val_accuracy: 0.0122
# Epoch 264/300
# 86/93 [==========================>...] - ETA: 0s - loss: 0.0741 - accuracy: 0.9762
# Epoch 00264: val_accuracy did not improve from 0.01362
# 93/93 [==============================] - 1s 6ms/step - loss: 0.0742 - accuracy: 0.9762 - val_loss: 4.7597 - val_accuracy: 0.0122
# Epoch 265/300
# 90/93 [============================>.] - ETA: 0s - loss: 0.0736 - accuracy: 0.9761
# Epoch 00265: val_accuracy did not improve from 0.01362
# 93/93 [==============================] - 1s 6ms/step - loss: 0.0737 - accuracy: 0.9760 - val_loss: 4.7302 - val_accuracy: 0.0121
# Epoch 266/300
# 88/93 [===========================>..] - ETA: 0s - loss: 0.0734 - accuracy: 0.9763
# Epoch 00266: val_accuracy did not improve from 0.01362
# 93/93 [==============================] - 1s 6ms/step - loss: 0.0734 - accuracy: 0.9763 - val_loss: 4.7074 - val_accuracy: 0.0126
# Epoch 267/300
# 89/93 [===========================>..] - ETA: 0s - loss: 0.0740 - accuracy: 0.9760
# Epoch 00267: val_accuracy did not improve from 0.01362
# 93/93 [==============================] - 1s 6ms/step - loss: 0.0743 - accuracy: 0.9760 - val_loss: 4.7572 - val_accuracy: 0.0124
# Epoch 268/300
# 87/93 [===========================>..] - ETA: 0s - loss: 0.0726 - accuracy: 0.9767
# Epoch 00268: val_accuracy did not improve from 0.01362
# 93/93 [==============================] - 1s 6ms/step - loss: 0.0728 - accuracy: 0.9766 - val_loss: 4.7150 - val_accuracy: 0.0130
# Epoch 269/300
# 91/93 [============================>.] - ETA: 0s - loss: 0.0735 - accuracy: 0.9763
# Epoch 00269: val_accuracy improved from 0.01362 to 0.01386, saving model to D:\Download\zyFile\Cyberthreat_Cognitive_System\CTCS_Code\attack_datasets\NSL-KDD\Model\NSL-KDD\AUG\LSTM\Mix_dataset_One_Hot_MI_ADASYN.h5
# 93/93 [==============================] - 1s 6ms/step - loss: 0.0735 - accuracy: 0.9763 - val_loss: 4.6981 - val_accuracy: 0.0139
# Epoch 270/300
# 88/93 [===========================>..] - ETA: 0s - loss: 0.0727 - accuracy: 0.9763
# Epoch 00270: val_accuracy did not improve from 0.01386
# 93/93 [==============================] - 1s 6ms/step - loss: 0.0727 - accuracy: 0.9764 - val_loss: 4.7900 - val_accuracy: 0.0133
# Epoch 271/300
# 91/93 [============================>.] - ETA: 0s - loss: 0.0734 - accuracy: 0.9761
# Epoch 00271: val_accuracy did not improve from 0.01386
# 93/93 [==============================] - 1s 6ms/step - loss: 0.0734 - accuracy: 0.9761 - val_loss: 4.8750 - val_accuracy: 0.0130
# Epoch 272/300
# 90/93 [============================>.] - ETA: 0s - loss: 0.0740 - accuracy: 0.9758
# Epoch 00272: val_accuracy did not improve from 0.01386
# 93/93 [==============================] - 1s 6ms/step - loss: 0.0739 - accuracy: 0.9758 - val_loss: 4.8116 - val_accuracy: 0.0125
# Epoch 273/300
# 92/93 [============================>.] - ETA: 0s - loss: 0.0725 - accuracy: 0.9767
# Epoch 00273: val_accuracy did not improve from 0.01386
# 93/93 [==============================] - 1s 6ms/step - loss: 0.0725 - accuracy: 0.9767 - val_loss: 4.7694 - val_accuracy: 0.0130
# Epoch 274/300
# 90/93 [============================>.] - ETA: 0s - loss: 0.0732 - accuracy: 0.9760
# Epoch 00274: val_accuracy did not improve from 0.01386
# 93/93 [==============================] - 1s 6ms/step - loss: 0.0733 - accuracy: 0.9760 - val_loss: 4.7974 - val_accuracy: 0.0126
# Epoch 275/300
# 85/93 [==========================>...] - ETA: 0s - loss: 0.0737 - accuracy: 0.9764
# Epoch 00275: val_accuracy did not improve from 0.01386
# 93/93 [==============================] - 1s 6ms/step - loss: 0.0732 - accuracy: 0.9766 - val_loss: 4.7519 - val_accuracy: 0.0127
# Epoch 276/300
# 87/93 [===========================>..] - ETA: 0s - loss: 0.0729 - accuracy: 0.9762
# Epoch 00276: val_accuracy did not improve from 0.01386
# 93/93 [==============================] - 1s 6ms/step - loss: 0.0732 - accuracy: 0.9760 - val_loss: 4.7194 - val_accuracy: 0.0130
# Epoch 277/300
# 87/93 [===========================>..] - ETA: 0s - loss: 0.0725 - accuracy: 0.9768
# Epoch 00277: val_accuracy did not improve from 0.01386
# 93/93 [==============================] - 1s 6ms/step - loss: 0.0725 - accuracy: 0.9768 - val_loss: 4.7091 - val_accuracy: 0.0131
# Epoch 278/300
# 90/93 [============================>.] - ETA: 0s - loss: 0.0722 - accuracy: 0.9765
# Epoch 00278: val_accuracy did not improve from 0.01386
# 93/93 [==============================] - 1s 6ms/step - loss: 0.0724 - accuracy: 0.9764 - val_loss: 4.7379 - val_accuracy: 0.0130
# Epoch 279/300
# 92/93 [============================>.] - ETA: 0s - loss: 0.0720 - accuracy: 0.9767
# Epoch 00279: val_accuracy did not improve from 0.01386
# 93/93 [==============================] - 1s 6ms/step - loss: 0.0720 - accuracy: 0.9767 - val_loss: 4.6294 - val_accuracy: 0.0135
# Epoch 280/300
# 84/93 [==========================>...] - ETA: 0s - loss: 0.0725 - accuracy: 0.9766
# Epoch 00280: val_accuracy did not improve from 0.01386
# 93/93 [==============================] - 1s 6ms/step - loss: 0.0723 - accuracy: 0.9767 - val_loss: 4.7539 - val_accuracy: 0.0126
# Epoch 281/300
# 87/93 [===========================>..] - ETA: 0s - loss: 0.0727 - accuracy: 0.9766
# Epoch 00281: val_accuracy did not improve from 0.01386
# 93/93 [==============================] - 1s 6ms/step - loss: 0.0723 - accuracy: 0.9768 - val_loss: 4.6620 - val_accuracy: 0.0138
# Epoch 282/300
# 88/93 [===========================>..] - ETA: 0s - loss: 0.0719 - accuracy: 0.9767
# Epoch 00282: val_accuracy did not improve from 0.01386
# 93/93 [==============================] - 1s 6ms/step - loss: 0.0721 - accuracy: 0.9766 - val_loss: 4.7028 - val_accuracy: 0.0131
# Epoch 283/300
# 87/93 [===========================>..] - ETA: 0s - loss: 0.0721 - accuracy: 0.9765
# Epoch 00283: val_accuracy did not improve from 0.01386
# 93/93 [==============================] - 1s 6ms/step - loss: 0.0718 - accuracy: 0.9766 - val_loss: 4.7373 - val_accuracy: 0.0137
# Epoch 284/300
# 90/93 [============================>.] - ETA: 0s - loss: 0.0721 - accuracy: 0.9768
# Epoch 00284: val_accuracy improved from 0.01386 to 0.01407, saving model to D:\Download\zyFile\Cyberthreat_Cognitive_System\CTCS_Code\attack_datasets\NSL-KDD\Model\NSL-KDD\AUG\LSTM\Mix_dataset_One_Hot_MI_ADASYN.h5
# 93/93 [==============================] - 1s 6ms/step - loss: 0.0720 - accuracy: 0.9768 - val_loss: 4.6943 - val_accuracy: 0.0141
# Epoch 285/300
# 86/93 [==========================>...] - ETA: 0s - loss: 0.0723 - accuracy: 0.9765
# Epoch 00285: val_accuracy did not improve from 0.01407
# 93/93 [==============================] - 1s 6ms/step - loss: 0.0723 - accuracy: 0.9766 - val_loss: 4.7017 - val_accuracy: 0.0134
# Epoch 286/300
# 90/93 [============================>.] - ETA: 0s - loss: 0.0717 - accuracy: 0.9772
# Epoch 00286: val_accuracy improved from 0.01407 to 0.01758, saving model to D:\Download\zyFile\Cyberthreat_Cognitive_System\CTCS_Code\attack_datasets\NSL-KDD\Model\NSL-KDD\AUG\LSTM\Mix_dataset_One_Hot_MI_ADASYN.h5
# 93/93 [==============================] - 1s 6ms/step - loss: 0.0716 - accuracy: 0.9772 - val_loss: 4.5318 - val_accuracy: 0.0176
# Epoch 287/300
# 89/93 [===========================>..] - ETA: 0s - loss: 0.0719 - accuracy: 0.9766
# Epoch 00287: val_accuracy did not improve from 0.01758
# 93/93 [==============================] - 1s 6ms/step - loss: 0.0721 - accuracy: 0.9765 - val_loss: 4.6570 - val_accuracy: 0.0162
# Epoch 288/300
# 90/93 [============================>.] - ETA: 0s - loss: 0.0719 - accuracy: 0.9765
# Epoch 00288: val_accuracy did not improve from 0.01758
# 93/93 [==============================] - 1s 6ms/step - loss: 0.0718 - accuracy: 0.9766 - val_loss: 4.6033 - val_accuracy: 0.0154
# Epoch 289/300
# 91/93 [============================>.] - ETA: 0s - loss: 0.0713 - accuracy: 0.9770
# Epoch 00289: val_accuracy did not improve from 0.01758
# 93/93 [==============================] - 1s 6ms/step - loss: 0.0714 - accuracy: 0.9770 - val_loss: 4.8037 - val_accuracy: 0.0157
# Epoch 290/300
# 91/93 [============================>.] - ETA: 0s - loss: 0.0704 - accuracy: 0.9775
# Epoch 00290: val_accuracy did not improve from 0.01758
# 93/93 [==============================] - 1s 6ms/step - loss: 0.0705 - accuracy: 0.9774 - val_loss: 4.7049 - val_accuracy: 0.0162
# Epoch 291/300
# 89/93 [===========================>..] - ETA: 0s - loss: 0.0721 - accuracy: 0.9767
# Epoch 00291: val_accuracy did not improve from 0.01758
# 93/93 [==============================] - 1s 6ms/step - loss: 0.0720 - accuracy: 0.9767 - val_loss: 4.7297 - val_accuracy: 0.0170
# Epoch 292/300
# 92/93 [============================>.] - ETA: 0s - loss: 0.0709 - accuracy: 0.9768
# Epoch 00292: val_accuracy did not improve from 0.01758
# 93/93 [==============================] - 1s 6ms/step - loss: 0.0710 - accuracy: 0.9767 - val_loss: 4.6942 - val_accuracy: 0.0171
# Epoch 293/300
# 89/93 [===========================>..] - ETA: 0s - loss: 0.0709 - accuracy: 0.9770
# Epoch 00293: val_accuracy did not improve from 0.01758
# 93/93 [==============================] - 1s 6ms/step - loss: 0.0711 - accuracy: 0.9769 - val_loss: 4.7023 - val_accuracy: 0.0175
# Epoch 294/300
# 87/93 [===========================>..] - ETA: 0s - loss: 0.0710 - accuracy: 0.9770
# Epoch 00294: val_accuracy did not improve from 0.01758
# 93/93 [==============================] - 1s 6ms/step - loss: 0.0712 - accuracy: 0.9770 - val_loss: 4.8617 - val_accuracy: 0.0146
# Epoch 295/300
# 87/93 [===========================>..] - ETA: 0s - loss: 0.0706 - accuracy: 0.9770
# Epoch 00295: val_accuracy did not improve from 0.01758
# 93/93 [==============================] - 1s 6ms/step - loss: 0.0706 - accuracy: 0.9771 - val_loss: 4.6375 - val_accuracy: 0.0149
# Epoch 296/300
# 86/93 [==========================>...] - ETA: 0s - loss: 0.0709 - accuracy: 0.9771
# Epoch 00296: val_accuracy did not improve from 0.01758
# 93/93 [==============================] - 1s 6ms/step - loss: 0.0713 - accuracy: 0.9770 - val_loss: 4.6466 - val_accuracy: 0.0167
# Epoch 297/300
# 87/93 [===========================>..] - ETA: 0s - loss: 0.0700 - accuracy: 0.9774
# Epoch 00297: val_accuracy did not improve from 0.01758
# 93/93 [==============================] - 1s 6ms/step - loss: 0.0702 - accuracy: 0.9773 - val_loss: 4.5957 - val_accuracy: 0.0167
# Epoch 298/300
# 85/93 [==========================>...] - ETA: 0s - loss: 0.0713 - accuracy: 0.9768
# Epoch 00298: val_accuracy did not improve from 0.01758
# 93/93 [==============================] - 1s 6ms/step - loss: 0.0709 - accuracy: 0.9770 - val_loss: 4.5790 - val_accuracy: 0.0172
# Epoch 299/300
# 87/93 [===========================>..] - ETA: 0s - loss: 0.0702 - accuracy: 0.9776
# Epoch 00299: val_accuracy did not improve from 0.01758
# 93/93 [==============================] - 1s 6ms/step - loss: 0.0701 - accuracy: 0.9776 - val_loss: 4.6780 - val_accuracy: 0.0173
# Epoch 300/300
# 88/93 [===========================>..] - ETA: 0s - loss: 0.0710 - accuracy: 0.9768
# Epoch 00300: val_accuracy improved from 0.01758 to 0.01851, saving model to D:\Download\zyFile\Cyberthreat_Cognitive_System\CTCS_Code\attack_datasets\NSL-KDD\Model\NSL-KDD\AUG\LSTM\Mix_dataset_One_Hot_MI_ADASYN.h5
# 93/93 [==============================] - 1s 6ms/step - loss: 0.0709 - accuracy: 0.9769 - val_loss: 4.4614 - val_accuracy: 0.0185

# %%
# 预测测试集
y_pred = model.predict(x_test)
# 计算测试集上的损失值和准确率
test_loss, test_acc = model.evaluate(x_test, y_test, verbose=0)
print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_acc*100:.2f}")
# Out:
# Test Loss: 0.0877
# Test Accuracy: 97.56

# %%
# 准确率曲线
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.axhline(y=test_acc, color='g', linestyle='--', label='Test Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# 损失曲线
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.axhline(y=test_loss, color='g', linestyle='--', label='Test Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
    
plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, confusion_matrix, roc_curve, auc, matthews_corrcoef
from keras.utils import np_utils
import numpy as np
import matplotlib.pyplot as plt

label_mapping = ['normal', 'dos', 'probe', 'r2l', 'u2r']
class_names = label_mapping

# Assuming y_pred is the raw output predictions from the model, you need to convert these to class labels for some metrics
# Convert probabilities to class labels
y_pred_classes = np.argmax(y_pred, axis=1)
y_test_classes = np.argmax(y_test, axis=1)  # Assuming y_test is already one-hot encoded, convert it back

# Generate confusion matrix
conf_matrix = confusion_matrix(y_test_classes, y_pred_classes)

# Visualize confusion matrix
plt.figure(figsize=(10, 7))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()

# Calculate metrics
recall = recall_score(y_test_classes, y_pred_classes, average='weighted')
precision = precision_score(y_test_classes, y_pred_classes, average='weighted')
f1 = f1_score(y_test_classes, y_pred_classes, average='weighted')

def fdr_score(y_true, y_pred):
    cm = confusion_matrix(y_true, y_pred)
    false_discoveries = np.sum(cm, axis=0) - np.diag(cm)
    total_predictions = np.sum(cm, axis=0)
    with np.errstate(divide='ignore', invalid='ignore'):
        fdrs = np.true_divide(false_discoveries, total_predictions)
        fdrs[np.isnan(fdrs)] = 0
    return np.mean(fdrs)

fdr = fdr_score(y_test_classes, y_pred_classes)

# Function to calculate MCC for a binary classification problem
# Adapted for multi-class by averaging over all classes
def mcc_score(y_true, y_pred):
    mcc = np.array([matthews_corrcoef(y_true == k, y_pred == k) for k in np.unique(y_true)])
    return np.nanmean(mcc)  # Averaging MCC scores over all classes

average_mcc = mcc_score(y_test_classes, y_pred_classes)

# Convert metrics to percentages
recall_percent = f"{recall * 100:.2f}%"
precision_percent = f"{precision * 100:.2f}%"
f1_percent = f"{f1 * 100:.2f}%"
tdr_percent = f"{(1-fdr) * 100:.2f}%"
average_mcc_percent = f"{average_mcc * 100:.2f}%"
# Out:
# C:\Users\23076\anaconda3\envs\tensorflow\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
print(f"Precision: {precision_percent}")
print(f"Recall: {recall_percent}")
print(f"F1 Score: {f1_percent}")
print(f"Average MCC: {average_mcc_percent}")
print(f"True Discovery Rate: {tdr_percent}")
# Out:
# Precision: 98.13%
# Recall: 97.56%
# F1 Score: 97.71%
# Average MCC: 73.58%
# True Discovery Rate: 91.03%

# %%
from sklearn.metrics import roc_curve, auc
from scipy import interp
from sklearn.preprocessing import label_binarize
import matplotlib.pyplot as plt
from itertools import cycle

# 如果y_test不是one-hot编码的，先将其转换
y_test_binarized = label_binarize(y_test_classes, classes=np.unique(y_test_classes))
n_classes = y_test_binarized.shape[1]

# 计算每个类的ROC曲线和ROC面积
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test_binarized[:, i], y_pred[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# 绘制所有类的ROC曲线
plt.figure(figsize=(10, 10))
colors = cycle(['aqua', 'darkorange', 'cornflowerblue', 'deeppink', 'navy'])
for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=2,
             label='Class {0} (area = {1:0.4f})'.format(class_names[i], roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--', lw=2)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Multi-class ROC Curve')
# 将图例放到图像外面并放大字体
plt.legend(loc='lower right', fontsize='25')
# 调整布局以防止图例被裁剪
plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import precision_recall_curve, auc
from sklearn.preprocessing import label_binarize
import matplotlib.pyplot as plt
import numpy as np

# 假设您已经有了y_pred，这是模型对测试集的预测概率
# 如果y_pred不是概率分数，请用model.predict(x_test)替换下面的y_score
y_score = y_pred  # 确保这是一个概率分数矩阵

# 将真实标签转换为 one-hot 编码
# 注意这里y_test_classes是真实的类标签，需要转换为one-hot编码形式
y_true_bin = label_binarize(y_test_classes, classes=np.unique(y_test_classes))

# 确定类别数和类别名称
n_classes = y_true_bin.shape[1]
class_names = ['normal', 'dos', 'probe', 'r2l', 'u2r']  # 举例，根据实际情况调整
    
# 创建一个新的图表
plt.figure(figsize=(10, 10))

# 为每个类别绘制PR曲线，并记录AUC值
auc_scores = []
for i in range(n_classes):
    precision, recall, _ = precision_recall_curve(y_true_bin[:, i], y_score[:, i])
    auc_score = auc(recall, precision)
    auc_scores.append(auc_score)
    plt.plot(recall, precision, marker='.', label='Class {} (AUC = {:.4f})'.format(class_names[i], auc_score))

# 设置图表的其他属性
plt.title('Precision-Recall Curve for Multiple Classes')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.legend(fontsize=14)
# 将图例放置在图像的右侧外部
plt.legend(bbox_to_anchor=(1, 1), fontsize=14)
# 展示图表
plt.show()
