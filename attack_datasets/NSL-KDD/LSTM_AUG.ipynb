# %%
import pandas as pd
from sklearn import preprocessing
from sklearn.decomposition import PCA
import numpy as np
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
# 加载数据
file_path_Mix_dataset_One_Hot = r"D:\Download\zyFile\Cyberthreat_Cognitive_System\CTCS_Code\attack_datasets\NSL-KDD\Mix_dataset_One_Hot.csv"
file_path_Mix_dataset_One_Hot_LDA = r"D:\Download\zyFile\Cyberthreat_Cognitive_System\CTCS_Code\attack_datasets\NSL-KDD\Mix_dataset_One_Hot_LDA.csv"
file_path_Mix_dataset_One_Hot_PCA = r"D:\Download\zyFile\Cyberthreat_Cognitive_System\CTCS_Code\attack_datasets\NSL-KDD\Mix_dataset_One_Hot_PCA.csv"
file_path_Mix_dataset_One_Hot_MI = r"D:\Download\zyFile\Cyberthreat_Cognitive_System\CTCS_Code\attack_datasets\NSL-KDD\Mix_dataset_One_Hot_MI.csv"
file_path_Mix_dataset_One_Hot_Pearson = r"D:\Download\zyFile\Cyberthreat_Cognitive_System\CTCS_Code\attack_datasets\NSL-KDD\Mix_dataset_One_Hot_Pearson.csv"

file_path_Mix_dataset_Label_Encoding = r"D:\Download\zyFile\Cyberthreat_Cognitive_System\CTCS_Code\attack_datasets\NSL-KDD\Mix_dataset_Label_Encoding.csv"
file_path_Mix_dataset_Label_Encoding_LDA = r"D:\Download\zyFile\Cyberthreat_Cognitive_System\CTCS_Code\attack_datasets\NSL-KDD\Mix_dataset_Label_Encoding_LDA.csv"
file_path_Mix_dataset_Label_Encoding_PCA = r"D:\Download\zyFile\Cyberthreat_Cognitive_System\CTCS_Code\attack_datasets\NSL-KDD\Mix_dataset_Label_Encoding_PCA.csv"
file_path_Mix_dataset_Label_Encoding_MI = r"D:\Download\zyFile\Cyberthreat_Cognitive_System\CTCS_Code\attack_datasets\NSL-KDD\Mix_dataset_Label_Encoding_MI.csv"
file_path_Mix_dataset_Label_Encoding_Pearson = r"D:\Download\zyFile\Cyberthreat_Cognitive_System\CTCS_Code\attack_datasets\NSL-KDD\Mix_dataset_Label_Encoding_Pearson.csv"
# 加载数据
final_data = pd.read_csv(file_path_Mix_dataset_Label_Encoding_LDA, header=0)
final_data.head()
# Out:
#           0         1         2         3    4
# 0 -1.436753 -0.420748  0.096719  0.021667  0.0
# 1 -0.704986  2.178238 -0.260677  0.086633  0.0
# 2  4.105672 -0.544753  0.093153 -0.054848  1.0
# 3 -2.366745 -0.928266 -0.706220  0.167995  0.0
# 4 -1.878593 -0.968902 -0.187279 -0.041789  0.0

# %%
X = final_data.iloc[:, :-1].values # 除目标属性外的数据集
y = final_data.iloc[:, -1].values   # 目标属性（标签）

# %%
# 分割数据集
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42, stratify=y)

# %%
from collections import Counter
from imblearn.over_sampling import SMOTE

# 初始化 SMOTE 对象
smote = SMOTE()

# 对训练集进行重采样
X_train, y_train  = smote.fit_resample(X_train, y_train)

# 打印重采样后的数据规模
print(f'重采样后的数据规模')
print(f'X_train_resampled shape: {X_train.shape}')
print(f'y_train_resampled shape: {y_train.shape}')
print(Counter(y_train))
# Out:
# 重采样后的数据规模
# X_train_resampled shape: (288950, 4)
# y_train_resampled shape: (288950,)
# Counter({1.0: 57790, 0.0: 57790, 3.0: 57790, 2.0: 57790, 4.0: 57790})

# %%
# from collections import Counter
# from imblearn.over_sampling import ADASYN
# 
# # 初始化 ADASYN 对象
# adasyn = ADASYN()
# 
# # 对训练集进行重采样
# X_train, y_train = adasyn.fit_resample(X_train, y_train)
# 
# # 打印重采样后的数据规模
# print(f'重采样后的数据规模')
# print(f'X_train_resampled shape: {X_train.shape}')
# print(f'y_train_resampled shape: {y_train.shape}')
# print(Counter(y_train))

# %%
# 重塑训练数据和测试数据以适配模型的输入 (假设每个样本只有单个时间步长)
x_train = np.reshape(X_train, (X_train.shape[0], 1, X_train.shape[1]))
x_test = np.reshape(X_test, (X_test.shape[0], 1, X_test.shape[1]))

# %%
# 对于多分类问题，标签y需要进行one-hot编码
from keras.utils import np_utils
y_train = np_utils.to_categorical(y_train)
y_test = np_utils.to_categorical(y_test)

# %%
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout, Bidirectional

# 初始化顺序模型
model = Sequential()

# 修改这里的input_shape以匹配实际的特征数量
model.add(Bidirectional(LSTM(100, return_sequences=True), input_shape=(1, 4)))
model.add(Dropout(0.5))
# 添加更多的LSTM层或其他类型的层
model.add(Bidirectional(LSTM(50)))
model.add(Dropout(0.5))

# 输出层，使用softmax激活函数，适用于多分类问题
model.add(Dense(5, activation='softmax'))
# 编译模型
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# 打印模型概述信息
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional (Bidirectiona  (None, 1, 200)           84000
#  l)
#
#  dropout (Dropout)           (None, 1, 200)            0
#
#  bidirectional_1 (Bidirectio  (None, 100)              100400
#  nal)
#
#  dropout_1 (Dropout)         (None, 100)               0
#
#  dense (Dense)               (None, 5)                 505
#
# =================================================================
# Total params: 184,905
# Trainable params: 184,905
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger

# 定义模型检查点回调
checkpoint = ModelCheckpoint(
    r"D:\Download\zyFile\Cyberthreat_Cognitive_System\CTCS_Code\attack_datasets\NSL-KDD\Model\NSL-KDD\AUG\LSTM\Mix_dataset_Label_Encoding_LDA_SMOTE.h5",
    monitor='val_accuracy',  # 监视验证集的准确率
    verbose=1,               # 打印出详细日志
    save_best_only=True,     # 只保存在验证集上准确率最高的模型
    mode='max'               # 'max'表示监视的指标（val_accuracy）需要被最大化
)

# 定义CSV日志记录回调
csv_logger = CSVLogger(
    r"D:\Download\zyFile\Cyberthreat_Cognitive_System\CTCS_Code\attack_datasets\NSL-KDD\Model\NSL-KDD\AUG\LSTM\CSV\Mix_dataset_Label_Encoding_LDA_SMOTE.csv",
    separator=",",
    append=False  # 每次开始训练都重新写日志文件
)

# 使用调整后的fit方法开始训练
history = model.fit(
    x_train,
    y_train,
    epochs=300,  # 训练100个epoch
    batch_size=2500,  # 每个批次的样本数
    validation_split=0.2,  # 使用20%的训练数据作为验证集
    callbacks=[checkpoint, csv_logger]  # 使用回调函数
)
# Out:
# Epoch 1/300
# 88/93 [===========================>..] - ETA: 0s - loss: 0.8004 - accuracy: 0.8181
# Epoch 00001: val_accuracy improved from -inf to 0.00118, saving model to D:\Download\zyFile\Cyberthreat_Cognitive_System\CTCS_Code\attack_datasets\NSL-KDD\Model\NSL-KDD\AUG\LSTM\Mix_dataset_Label_Encoding_LDA_SMOTE.h5
# 93/93 [==============================] - 4s 12ms/step - loss: 0.7818 - accuracy: 0.8198 - val_loss: 4.1861 - val_accuracy: 0.0012
# Epoch 2/300
# 91/93 [============================>.] - ETA: 0s - loss: 0.3916 - accuracy: 0.8634
# Epoch 00002: val_accuracy did not improve from 0.00118
# 93/93 [==============================] - 1s 6ms/step - loss: 0.3913 - accuracy: 0.8635 - val_loss: 4.5215 - val_accuracy: 0.0012
# Epoch 3/300
# 89/93 [===========================>..] - ETA: 0s - loss: 0.3689 - accuracy: 0.8731
# Epoch 00003: val_accuracy improved from 0.00118 to 0.00137, saving model to D:\Download\zyFile\Cyberthreat_Cognitive_System\CTCS_Code\attack_datasets\NSL-KDD\Model\NSL-KDD\AUG\LSTM\Mix_dataset_Label_Encoding_LDA_SMOTE.h5
# 93/93 [==============================] - 1s 6ms/step - loss: 0.3686 - accuracy: 0.8733 - val_loss: 4.6699 - val_accuracy: 0.0014
# Epoch 4/300
# 90/93 [============================>.] - ETA: 0s - loss: 0.3571 - accuracy: 0.8786
# Epoch 00004: val_accuracy improved from 0.00137 to 0.00138, saving model to D:\Download\zyFile\Cyberthreat_Cognitive_System\CTCS_Code\attack_datasets\NSL-KDD\Model\NSL-KDD\AUG\LSTM\Mix_dataset_Label_Encoding_LDA_SMOTE.h5
# 93/93 [==============================] - 1s 6ms/step - loss: 0.3567 - accuracy: 0.8788 - val_loss: 4.5195 - val_accuracy: 0.0014
# Epoch 5/300
# 88/93 [===========================>..] - ETA: 0s - loss: 0.3482 - accuracy: 0.8834
# Epoch 00005: val_accuracy improved from 0.00138 to 0.00140, saving model to D:\Download\zyFile\Cyberthreat_Cognitive_System\CTCS_Code\attack_datasets\NSL-KDD\Model\NSL-KDD\AUG\LSTM\Mix_dataset_Label_Encoding_LDA_SMOTE.h5
# 93/93 [==============================] - 1s 6ms/step - loss: 0.3478 - accuracy: 0.8835 - val_loss: 4.4753 - val_accuracy: 0.0014
# Epoch 6/300
# 91/93 [============================>.] - ETA: 0s - loss: 0.3394 - accuracy: 0.8870
# Epoch 00006: val_accuracy improved from 0.00140 to 0.00286, saving model to D:\Download\zyFile\Cyberthreat_Cognitive_System\CTCS_Code\attack_datasets\NSL-KDD\Model\NSL-KDD\AUG\LSTM\Mix_dataset_Label_Encoding_LDA_SMOTE.h5
# 93/93 [==============================] - 1s 6ms/step - loss: 0.3391 - accuracy: 0.8870 - val_loss: 4.5503 - val_accuracy: 0.0029
# Epoch 7/300
# 91/93 [============================>.] - ETA: 0s - loss: 0.3301 - accuracy: 0.8891
# Epoch 00007: val_accuracy improved from 0.00286 to 0.00722, saving model to D:\Download\zyFile\Cyberthreat_Cognitive_System\CTCS_Code\attack_datasets\NSL-KDD\Model\NSL-KDD\AUG\LSTM\Mix_dataset_Label_Encoding_LDA_SMOTE.h5
# 93/93 [==============================] - 1s 6ms/step - loss: 0.3300 - accuracy: 0.8892 - val_loss: 4.5108 - val_accuracy: 0.0072
# Epoch 8/300
# 93/93 [==============================] - ETA: 0s - loss: 0.3212 - accuracy: 0.8899
# Epoch 00008: val_accuracy improved from 0.00722 to 0.00851, saving model to D:\Download\zyFile\Cyberthreat_Cognitive_System\CTCS_Code\attack_datasets\NSL-KDD\Model\NSL-KDD\AUG\LSTM\Mix_dataset_Label_Encoding_LDA_SMOTE.h5
# 93/93 [==============================] - 1s 7ms/step - loss: 0.3212 - accuracy: 0.8899 - val_loss: 4.4020 - val_accuracy: 0.0085
# Epoch 9/300
# 92/93 [============================>.] - ETA: 0s - loss: 0.3111 - accuracy: 0.8913
# Epoch 00009: val_accuracy improved from 0.00851 to 0.03719, saving model to D:\Download\zyFile\Cyberthreat_Cognitive_System\CTCS_Code\attack_datasets\NSL-KDD\Model\NSL-KDD\AUG\LSTM\Mix_dataset_Label_Encoding_LDA_SMOTE.h5
# 93/93 [==============================] - 1s 7ms/step - loss: 0.3112 - accuracy: 0.8913 - val_loss: 4.3631 - val_accuracy: 0.0372
# Epoch 10/300
# 90/93 [============================>.] - ETA: 0s - loss: 0.3027 - accuracy: 0.8925
# Epoch 00010: val_accuracy did not improve from 0.03719
# 93/93 [==============================] - 1s 6ms/step - loss: 0.3022 - accuracy: 0.8926 - val_loss: 4.4150 - val_accuracy: 0.0348
# Epoch 11/300
# 88/93 [===========================>..] - ETA: 0s - loss: 0.2906 - accuracy: 0.8952
# Epoch 00011: val_accuracy improved from 0.03719 to 0.09574, saving model to D:\Download\zyFile\Cyberthreat_Cognitive_System\CTCS_Code\attack_datasets\NSL-KDD\Model\NSL-KDD\AUG\LSTM\Mix_dataset_Label_Encoding_LDA_SMOTE.h5
# 93/93 [==============================] - 1s 6ms/step - loss: 0.2911 - accuracy: 0.8950 - val_loss: 4.2531 - val_accuracy: 0.0957
# Epoch 12/300
# 89/93 [===========================>..] - ETA: 0s - loss: 0.2818 - accuracy: 0.8982
# Epoch 00012: val_accuracy did not improve from 0.09574
# 93/93 [==============================] - 1s 6ms/step - loss: 0.2814 - accuracy: 0.8984 - val_loss: 4.3819 - val_accuracy: 0.0612
# Epoch 13/300
# 92/93 [============================>.] - ETA: 0s - loss: 0.2735 - accuracy: 0.9015
# Epoch 00013: val_accuracy did not improve from 0.09574
# 93/93 [==============================] - 1s 6ms/step - loss: 0.2734 - accuracy: 0.9016 - val_loss: 4.7357 - val_accuracy: 0.0077
# Epoch 14/300
# 93/93 [==============================] - ETA: 0s - loss: 0.2679 - accuracy: 0.9039
# Epoch 00014: val_accuracy improved from 0.09574 to 0.09839, saving model to D:\Download\zyFile\Cyberthreat_Cognitive_System\CTCS_Code\attack_datasets\NSL-KDD\Model\NSL-KDD\AUG\LSTM\Mix_dataset_Label_Encoding_LDA_SMOTE.h5
# 93/93 [==============================] - 1s 7ms/step - loss: 0.2679 - accuracy: 0.9039 - val_loss: 4.4560 - val_accuracy: 0.0984
# Epoch 15/300
# 87/93 [===========================>..] - ETA: 0s - loss: 0.2623 - accuracy: 0.9067
# Epoch 00015: val_accuracy improved from 0.09839 to 0.11062, saving model to D:\Download\zyFile\Cyberthreat_Cognitive_System\CTCS_Code\attack_datasets\NSL-KDD\Model\NSL-KDD\AUG\LSTM\Mix_dataset_Label_Encoding_LDA_SMOTE.h5
# 93/93 [==============================] - 1s 7ms/step - loss: 0.2620 - accuracy: 0.9068 - val_loss: 4.3249 - val_accuracy: 0.1106
# Epoch 16/300
# 86/93 [==========================>...] - ETA: 0s - loss: 0.2567 - accuracy: 0.9093
# Epoch 00016: val_accuracy did not improve from 0.11062
# 93/93 [==============================] - 1s 6ms/step - loss: 0.2569 - accuracy: 0.9092 - val_loss: 4.5028 - val_accuracy: 0.0991
# Epoch 17/300
# 89/93 [===========================>..] - ETA: 0s - loss: 0.2530 - accuracy: 0.9109
# Epoch 00017: val_accuracy did not improve from 0.11062
# 93/93 [==============================] - 1s 6ms/step - loss: 0.2528 - accuracy: 0.9110 - val_loss: 4.8019 - val_accuracy: 0.0517
# Epoch 18/300
# 92/93 [============================>.] - ETA: 0s - loss: 0.2477 - accuracy: 0.9127
# Epoch 00018: val_accuracy did not improve from 0.11062
# 93/93 [==============================] - 1s 6ms/step - loss: 0.2477 - accuracy: 0.9127 - val_loss: 4.5800 - val_accuracy: 0.0999
# Epoch 19/300
# 89/93 [===========================>..] - ETA: 0s - loss: 0.2442 - accuracy: 0.9146
# Epoch 00019: val_accuracy improved from 0.11062 to 0.12322, saving model to D:\Download\zyFile\Cyberthreat_Cognitive_System\CTCS_Code\attack_datasets\NSL-KDD\Model\NSL-KDD\AUG\LSTM\Mix_dataset_Label_Encoding_LDA_SMOTE.h5
# 93/93 [==============================] - 1s 6ms/step - loss: 0.2440 - accuracy: 0.9148 - val_loss: 4.5122 - val_accuracy: 0.1232
# Epoch 20/300
# 87/93 [===========================>..] - ETA: 0s - loss: 0.2394 - accuracy: 0.9165
# Epoch 00020: val_accuracy improved from 0.12322 to 0.12942, saving model to D:\Download\zyFile\Cyberthreat_Cognitive_System\CTCS_Code\attack_datasets\NSL-KDD\Model\NSL-KDD\AUG\LSTM\Mix_dataset_Label_Encoding_LDA_SMOTE.h5
# 93/93 [==============================] - 1s 6ms/step - loss: 0.2397 - accuracy: 0.9164 - val_loss: 4.5002 - val_accuracy: 0.1294
# Epoch 21/300
# 91/93 [============================>.] - ETA: 0s - loss: 0.2371 - accuracy: 0.9173
# Epoch 00021: val_accuracy did not improve from 0.12942
# 93/93 [==============================] - 1s 6ms/step - loss: 0.2368 - accuracy: 0.9173 - val_loss: 4.5734 - val_accuracy: 0.1031
# Epoch 22/300
# 89/93 [===========================>..] - ETA: 0s - loss: 0.2337 - accuracy: 0.9187
# Epoch 00022: val_accuracy did not improve from 0.12942
# 93/93 [==============================] - 1s 6ms/step - loss: 0.2335 - accuracy: 0.9188 - val_loss: 4.8112 - val_accuracy: 0.0489
# Epoch 23/300
# 90/93 [============================>.] - ETA: 0s - loss: 0.2297 - accuracy: 0.9201
# Epoch 00023: val_accuracy improved from 0.12942 to 0.13449, saving model to D:\Download\zyFile\Cyberthreat_Cognitive_System\CTCS_Code\attack_datasets\NSL-KDD\Model\NSL-KDD\AUG\LSTM\Mix_dataset_Label_Encoding_LDA_SMOTE.h5
# 93/93 [==============================] - 1s 6ms/step - loss: 0.2299 - accuracy: 0.9200 - val_loss: 4.4647 - val_accuracy: 0.1345
# Epoch 24/300
# 90/93 [============================>.] - ETA: 0s - loss: 0.2282 - accuracy: 0.9208
# Epoch 00024: val_accuracy did not improve from 0.13449
# 93/93 [==============================] - 1s 6ms/step - loss: 0.2281 - accuracy: 0.9208 - val_loss: 4.6312 - val_accuracy: 0.0916
# Epoch 25/300
# 91/93 [============================>.] - ETA: 0s - loss: 0.2252 - accuracy: 0.9220
# Epoch 00025: val_accuracy did not improve from 0.13449
# 93/93 [==============================] - 1s 6ms/step - loss: 0.2250 - accuracy: 0.9221 - val_loss: 4.6249 - val_accuracy: 0.0510
# Epoch 26/300
# 91/93 [============================>.] - ETA: 0s - loss: 0.2219 - accuracy: 0.9232
# Epoch 00026: val_accuracy did not improve from 0.13449
# 93/93 [==============================] - 1s 6ms/step - loss: 0.2220 - accuracy: 0.9232 - val_loss: 4.5558 - val_accuracy: 0.1069
# Epoch 27/300
# 91/93 [============================>.] - ETA: 0s - loss: 0.2194 - accuracy: 0.9240
# Epoch 00027: val_accuracy did not improve from 0.13449
# 93/93 [==============================] - 1s 6ms/step - loss: 0.2195 - accuracy: 0.9240 - val_loss: 4.7226 - val_accuracy: 0.0662
# Epoch 28/300
# 90/93 [============================>.] - ETA: 0s - loss: 0.2165 - accuracy: 0.9244
# Epoch 00028: val_accuracy did not improve from 0.13449
# 93/93 [==============================] - 1s 6ms/step - loss: 0.
300
# 89/93 [===========================>..] - ETA: 0s - loss: 0.1608 - accuracy: 0.9444
# Epoch 00087: val_accuracy did not improve from 0.15250
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1607 - accuracy: 0.9444 - val_loss: 4.1428 - val_accuracy: 0.1253
# Epoch 88/300
# 89/93 [===========================>..] - ETA: 0s - loss: 0.1602 - accuracy: 0.9448
# Epoch 00088: val_accuracy did not improve from 0.15250
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1600 - accuracy: 0.9450 - val_loss: 4.1405 - val_accuracy: 0.1135
# Epoch 89/300
# 88/93 [===========================>..] - ETA: 0s - loss: 0.1589 - accuracy: 0.9449
# Epoch 00089: val_accuracy did not improve from 0.15250
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1593 - accuracy: 0.9448 - val_loss: 4.2047 - val_accuracy: 0.0793
# Epoch 90/300
# 87/93 [===========================>..] - ETA: 0s - loss: 0.1583 - accuracy: 0.9452
# Epoch 00090: val_accuracy did not improve from 0.15250
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1583 - accuracy: 0.9453 - val_loss: 4.1114 - val_accuracy: 0.1232
# Epoch 91/300
# 91/93 [============================>.] - ETA: 0s - loss: 0.1585 - accuracy: 0.9452
# Epoch 00091: val_accuracy did not improve from 0.15250
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1586 - accuracy: 0.9451 - val_loss: 4.2472 - val_accuracy: 0.0667
# Epoch 92/300
# 90/93 [============================>.] - ETA: 0s - loss: 0.1575 - accuracy: 0.9455
# Epoch 00092: val_accuracy did not improve from 0.15250
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1576 - accuracy: 0.9455 - val_loss: 4.1592 - val_accuracy: 0.0892
# Epoch 93/300
# 89/93 [===========================>..] - ETA: 0s - loss: 0.1578 - accuracy: 0.9454
# Epoch 00093: val_accuracy improved from 0.15250 to 0.19021, saving model to D:\Download\zyFile\Cyberthreat_Cognitive_System\CTCS_Code\attack_datasets\NSL-KDD\Model\NSL-KDD\AUG\LSTM\Mix_dataset_Label_Encoding_LDA_SMOTE.h5
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1575 - accuracy: 0.9456 - val_loss: 3.9355 - val_accuracy: 0.1902
# Epoch 94/300
# 90/93 [============================>.] - ETA: 0s - loss: 0.1572 - accuracy: 0.9456
# Epoch 00094: val_accuracy did not improve from 0.19021
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1570 - accuracy: 0.9458 - val_loss: 3.9298 - val_accuracy: 0.1824
# Epoch 95/300
# 89/93 [===========================>..] - ETA: 0s - loss: 0.1567 - accuracy: 0.9462
# Epoch 00095: val_accuracy did not improve from 0.19021
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1571 - accuracy: 0.9462 - val_loss: 4.0983 - val_accuracy: 0.1159
# Epoch 96/300
# 89/93 [===========================>..] - ETA: 0s - loss: 0.1558 - accuracy: 0.9465
# Epoch 00096: val_accuracy did not improve from 0.19021
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1560 - accuracy: 0.9465 - val_loss: 4.0465 - val_accuracy: 0.1493
# Epoch 97/300
# 87/93 [===========================>..] - ETA: 0s - loss: 0.1559 - accuracy: 0.9463
# Epoch 00097: val_accuracy did not improve from 0.19021
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1556 - accuracy: 0.9464 - val_loss: 3.9962 - val_accuracy: 0.1601
# Epoch 98/300
# 90/93 [============================>.] - ETA: 0s - loss: 0.1553 - accuracy: 0.9462
# Epoch 00098: val_accuracy did not improve from 0.19021
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1553 - accuracy: 0.9463 - val_loss: 4.0319 - val_accuracy: 0.1331
# Epoch 99/300
# 90/93 [============================>.] - ETA: 0s - loss: 0.1553 - accuracy: 0.9462
# Epoch 00099: val_accuracy did not improve from 0.19021
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1550 - accuracy: 0.9464 - val_loss: 4.0048 - val_accuracy: 0.1397
# Epoch 100/300
# 88/93 [===========================>..] - ETA: 0s - loss: 0.1551 - accuracy: 0.9462
# Epoch 00100: val_accuracy did not improve from 0.19021
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1549 - accuracy: 0.9463 - val_loss: 3.9872 - val_accuracy: 0.1637
# Epoch 101/300
# 89/93 [===========================>..] - ETA: 0s - loss: 0.1541 - accuracy: 0.9467
# Epoch 00101: val_accuracy did not improve from 0.19021
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1541 - accuracy: 0.9467 - val_loss: 3.9733 - val_accuracy: 0.1315
# Epoch 102/300
# 87/93 [===========================>..] - ETA: 0s - loss: 0.1537 - accuracy: 0.9471
# Epoch 00102: val_accuracy did not improve from 0.19021
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1538 - accuracy: 0.9471 - val_loss: 4.0156 - val_accuracy: 0.1024
# Epoch 103/300
# 87/93 [===========================>..] - ETA: 0s - loss: 0.1532 - accuracy: 0.9471
# Epoch 00103: val_accuracy did not improve from 0.19021
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1533 - accuracy: 0.9470 - val_loss: 3.9381 - val_accuracy: 0.1596
# Epoch 104/300
# 89/93 [===========================>..] - ETA: 0s - loss: 0.1540 - accuracy: 0.9467
# Epoch 00104: val_accuracy did not improve from 0.19021
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1538 - accuracy: 0.9468 - val_loss: 4.0484 - val_accuracy: 0.1356
# Epoch 105/300
# 90/93 [============================>.] - ETA: 0s - loss: 0.1525 - accuracy: 0.9469
# Epoch 00105: val_accuracy did not improve from 0.19021
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1525 - accuracy: 0.9469 - val_loss: 4.0354 - val_accuracy: 0.0925
# Epoch 106/300
# 89/93 [===========================>..] - ETA: 0s - loss: 0.1533 - accuracy: 0.9469
# Epoch 00106: val_accuracy did not improve from 0.19021
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1533 - accuracy: 0.9469 - val_loss: 3.9307 - val_accuracy: 0.1546
# Epoch 107/300
# 89/93 [===========================>..] - ETA: 0s - loss: 0.
300
# 91/93 [============================>.] - ETA: 0s - loss: 0.1459 - accuracy: 0.9490
# Epoch 00128: val_accuracy did not improve from 0.19021
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1457 - accuracy: 0.9490 - val_loss: 3.7419 - val_accuracy: 0.1898
# Epoch 129/300
# 91/93 [============================>.] - ETA: 0s - loss: 0.1470 - accuracy: 0.9490
# Epoch 00129: val_accuracy did not improve from 0.19021
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1468 - accuracy: 0.9491 - val_loss: 3.8416 - val_accuracy: 0.1608
# Epoch 130/300
# 91/93 [============================>.] - ETA: 0s - loss: 0.1460 - accuracy: 0.9491
# Epoch 00130: val_accuracy did not improve from 0.19021
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1463 - accuracy: 0.9490 - val_loss: 3.8185 - val_accuracy: 0.1234
# Epoch 131/300
# 89/93 [===========================>..] - ETA: 0s - loss: 0.1468 - accuracy: 0.9491
# Epoch 00131: val_accuracy did not improve from 0.19021
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1467 - accuracy: 0.9491 - val_loss: 3.7440 - val_accuracy: 0.1558
# Epoch 132/300
# 91/93 [============================>.] - ETA: 0s - loss: 0.1449 - accuracy: 0.9493
# Epoch 00132: val_accuracy did not improve from 0.19021
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1451 - accuracy: 0.9493 - val_loss: 3.8428 - val_accuracy: 0.1230
# Epoch 133/300
# 91/93 [============================>.] - ETA: 0s - loss: 0.1454 - accuracy: 0.9494
# Epoch 00133: val_accuracy did not improve from 0.19021
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1455 - accuracy: 0.9494 - val_loss: 3.8479 - val_accuracy: 0.1224
# Epoch 134/300
# 91/93 [============================>.] - ETA: 0s - loss: 0.1454 - accuracy: 0.9495
# Epoch 00134: val_accuracy did not improve from 0.19021
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1454 - accuracy: 0.9495 - val_loss: 3.8330 - val_accuracy: 0.1236
# Epoch 135/300
# 90/93 [============================>.] - ETA: 0s - loss: 0.1450 - accuracy: 0.9496
# Epoch 00135: val_accuracy did not improve from 0.19021
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1451 - accuracy: 0.9495 - val_loss: 3.6818 - val_accuracy: 0.1847
# Epoch 136/300
# 92/93 [============================>.] - ETA: 0s - loss: 0.1443 - accuracy: 0.9500
# Epoch 00136: val_accuracy did not improve from 0.19021
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1443 - accuracy: 0.9500 - val_loss: 3.8820 - val_accuracy: 0.1151
# Epoch 137/300
# 91/93 [============================>.] - ETA: 0s - loss: 0.1452 - accuracy: 0.9497
# Epoch 00137: val_accuracy did not improve from 0.19021
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1451 - accuracy: 0.9497 - val_loss: 3.8264 - val_accuracy: 0.1101
# Epoch 138/300
# 92/93 [============================>.] - ETA: 0s - loss: 0.1451 - accuracy: 0.9501
# Epoch 00138: val_accuracy did not improve from 0.19021
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1450 - accuracy: 0.9501 - val_loss: 3.7317 - val_accuracy: 0.1281
# Epoch 139/300
# 91/93 [============================>.] - ETA: 0s - loss: 0.1441 - accuracy: 0.9499
# Epoch 00139: val_accuracy did not improve from 0.19021
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1443 - accuracy: 0.9498 - val_loss: 3.7120 - val_accuracy: 0.1672
# Epoch 140/300
# 91/93 [============================>.] - ETA: 0s - loss: 0.1431 - accuracy: 0.9505
# Epoch 00140: val_accuracy did not improve from 0.19021
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1432 - accuracy: 0.9505 - val_loss: 3.6848 - val_accuracy: 0.1760
# Epoch 141/300
# 92/93 [============================>.] - ETA: 0s - loss: 0.1442 - accuracy: 0.9499
# Epoch 00141: val_accuracy did not improve from 0.19021
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1442 - accuracy: 0.9499 - val_loss: 3.8053 - val_accuracy: 0.1451
# Epoch 142/300
# 91/93 [============================>.] - ETA: 0s - loss: 0.1428 - accuracy: 0.9505
# Epoch 00142: val_accuracy did not improve from 0.19021
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1429 - accuracy: 0.9505 - val_loss: 3.6962 - val_accuracy: 0.1551
# Epoch 143/300
# 89/93 [===========================>..] - ETA: 0s - loss: 0.1429 - accuracy: 0.9497
# Epoch 00143: val_accuracy did not improve from 0.19021
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1429 - accuracy: 0.9498 - val_loss: 3.7721 - val_accuracy: 0.1541
# Epoch 144/300
# 91/93 [============================>.] - ETA: 0s - loss: 0.1440 - accuracy: 0.9500
# Epoch 00144: val_accuracy did not improve from 0.19021
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1437 - accuracy: 0.9501 - val_loss: 3.7730 - val_accuracy: 0.1385
# Epoch 145/300
# 92/93 [============================>.] - ETA: 0s - loss: 0.1424 - accuracy: 0.9506
# Epoch 00145: val_accuracy did not improve from 0.19021
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1424 - accuracy: 0.9506 - val_loss: 3.7027 - val_accuracy: 0.1546
# Epoch 146/300
# 91/93 [============================>.] - ETA: 0s - loss: 0.1423 - accuracy: 0.9510
# Epoch 00146: val_accuracy did not improve from 0.19021
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1423 - accuracy: 0.9509 - val_loss: 3.7312 - val_accuracy: 0.1470
# Epoch 147/300
# 89/93 [===========================>..] - ETA: 0s - loss: 0.1429 - accuracy: 0.9503
# Epoch 00147: val_accuracy did not improve from 0.19021
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1429 - accuracy: 0.9503 - val_loss: 3.7986 - val_accuracy: 0.1227
# Epoch 148/300
# 89/93 [===========================>..] - ETA: 0s - loss: 0.1415 - accuracy: 0.9511
# Epoch 00148: val_accuracy did not improve from 0.19021
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1415 - accuracy: 0.9510 - val_loss: 3.7626 - val_accuracy: 0.1543
# Epoch 149/300
# 93/93 [==============================] - ETA: 0s - loss: 0.1426 - accuracy: 0.9505
# Epoch 00149: val_accuracy did not improve from 0.19021
# 93/93 [==============================] - 1s 7ms/step - loss: 0.1426 - accuracy: 0.9505 - val_loss: 3.7626 - val_accuracy: 0.1391
# Epoch 150/300
# 91/93 [============================>.] - ETA: 0s - loss: 0.1424 - accuracy: 0.9509
# Epoch 00150: val_accuracy did not improve from 0.19021
# 93/93 [==============================] - 1s 7ms/step - loss: 0.1422 - accuracy: 0.9510 - val_loss: 3.7192 - val_accuracy: 0.1266
# Epoch 151/300
# 93/93 [==============================] - ETA: 0s - loss: 0.1422 - accuracy: 0.9506
# Epoch 00151: val_accuracy did not improve from 0.19021
# 93/93 [==============================] - 1s 7ms/step - loss: 0.1422 - accuracy: 0.9506 - val_loss: 3.7137 - val_accuracy: 0.1485
# Epoch 152/300
# 92/93 [============================>.] - ETA: 0s - loss: 0.1425 - accuracy: 0.9505
# Epoch 00152: val_accuracy did not improve from 0.19021
# 93/93 [==============================] - 1s 7ms/step - loss: 0.1424 - accuracy: 0.9505 - val_loss: 3.6662 - val_accuracy: 0.1848
# Epoch 153/300
# 85/93 [==========================>...] - ETA: 0s - loss: 0.1408 - accuracy: 0.9512
# Epoch 00153: val_accuracy did not improve from 0.19021
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1405 - accuracy: 0.9512 - val_loss: 3.7297 - val_accuracy: 0.1574
# Epoch 154/300
# 88/93 [===========================>..] - ETA: 0s - loss: 0.1408 - accuracy: 0.9509
# Epoch 00154: val_accuracy improved from 0.19021 to 0.19067, saving model to D:\Download\zyFile\Cyberthreat_Cognitive_System\CTCS_Code\attack_datasets\NSL-KDD\Model\NSL-KDD\AUG\LSTM\Mix_dataset_Label_Encoding_LDA_SMOTE.h5
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1408 - accuracy: 0.9509 - val_loss: 3.6727 - val_accuracy: 0.1907
# Epoch 155/300
# 89/93 [===========================>..] - ETA: 0s - loss: 0.1415 - accuracy: 0.9509
# Epoch 00155: val_accuracy did not improve from 0.19067
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1418 - accuracy: 0.9508 - val_loss: 3.6694 - val_accuracy: 0.1857
# Epoch 156/300
# 89/93 [===========================>..] - ETA: 0s - loss: 0.1414 - accuracy: 0.9512
# Epoch 00156: val_accuracy did not improve from 0.19067
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1413 - accuracy: 0.9513 - val_loss: 3.7603 - val_accuracy: 0.1389
# Epoch 157/300
# 93/93 [==============================] - ETA: 0s - loss: 0.1402 - accuracy: 0.9514
# Epoch 00157: val_accuracy improved from 0.19067 to 0.20000, saving model to D:\Download\zyFile\Cyberthreat_Cognitive_System\CTCS_Code\attack_datasets\NSL-KDD\Model\NSL-KDD\AUG\LSTM\Mix_dataset_Label_Encoding_LDA_SMOTE.h5
# 93/93 [==============================] - 1s 7ms/step - loss: 0.1402 - accuracy: 0.9514 - val_loss: 3.7313 - val_accuracy: 0.2000
# Epoch 158/300
# 85/93 [==========================>...] - ETA: 0s - loss: 0.1407 - accuracy: 0.9512
# Epoch 00158: val_accuracy did not improve from 0.20000
# 93/93 [==============================] - 1s 6ms/step - loss: 0.1407 - accuracy: 0.9512 - val_loss: 3.7022 - val_accuracy: 0.1873
# Epoch 159/300
# 92/93 [============================>.] - ETA: 0s - loss: 0.1398 - accuracy: 0.9518
# Epoch 00159: val_accuracy did not improve from 0.20000
# 93/93 [==============================] - 1s 7ms/step - loss: 0.1399 - accuracy: 0.9518 - val_loss: 3.7474 - val_accuracy: 0.1751
# Epoch 160/300
# 84/93 [==========================>...] - ETA: 0s - loss: 0.1409 - accuracy: 0.9510
# ...
# Epoch 245/300
# 86/93 [==========================>...] - ETA: 0s - loss: 0.1293 - accuracy: 0.9552
# Epoch 00245: val_accuracy did not improve from 0.23693
# 93/93 [==============================] - 1s 7ms/step - loss: 0.1295 - accuracy: 0.9550 - val_loss: 3.4662 - val_accuracy: 0.2165
# Epoch 246/300
# 93/93 [==============================] - ETA: 0s - loss: 0.1299 - accuracy: 0.9550
# Epoch 00246: val_accuracy did not improve from 0.23693
# 93/93 [==============================] - 1s 7ms/step - loss: 0.1299 - accuracy: 0.9550 - val_loss: 3.5365 - val_accuracy: 0.1904
# Epoch 247/300
# 91/93 [============================>.] - ETA: 0s - loss: 0.1285 - accuracy: 0.9554
# Epoch 00247: val_accuracy did not improve from 0.23693
# 93/93 [==============================] - 1s 7ms/step - loss: 0.1284 - accuracy: 0.9554 - val_loss: 3.6084 - val_accuracy: 0.1821
# Epoch 248/300
# 88/93 [===========================>..] - ETA: 0s - loss: 0.1295 - accuracy: 0.9553
# Epoch 00248: val_accuracy did not improve from 0.23693
# 93/93 [==============================] - 1s 7ms/step - loss: 0.1296 - accuracy: 0.9554 - val_loss: 3.5450 - val_accuracy: 0.2161
# Epoch 249/300
# 92/93 [============================>.] - ETA: 0s - loss: 0.1295 - accuracy: 0.9548
# Epoch 00249: val_accuracy did not improve from 0.23693
# 93/93 [==============================] - 1s 9ms/step - loss: 0.1294 - accuracy: 0.9548 - val_loss: 3.5408 - val_accuracy: 0.2059
# Epoch 250/300
# 88/93 [===========================>..] - ETA: 0s - loss: 0.1291 - accuracy: 0.9556
# Epoch 00250: val_accuracy did not improve from 0.23693
# 93/93 [==============================] - 1s 9ms/step - loss: 0.1291 - accuracy: 0.9556 - val_loss: 3.5806 - val_accuracy: 0.2153
# Epoch 251/300
# 92/93 [============================>.] - ETA: 0s - loss: 0.1292 - accuracy: 0.9553
# Epoch 00251: val_accuracy did not improve from 0.23693
# 93/93 [==============================] - 1s 7ms/step - loss: 0.1291 - accuracy: 0.9553 - val_loss: 3.5555 - val_accuracy: 0.2001
# Epoch 252/300
# 93/93 [==============================] - ETA: 0s - loss: 0.1279 - accuracy: 0.9558
# Epoch 00252: val_accuracy did not improve from 0.23693
# 93/93 [==============================] - 1s 7ms/step - loss: 0.1279 - accuracy: 0.9558 - val_loss: 3.4265 - val_accuracy: 0.2255
# Epoch 253/300
# 93/93 [==============================] - ETA: 0s - loss: 0.1289 - accuracy: 0.9550
# Epoch 00253: val_accuracy did not improve from 0.23693
# 93/93 [==============================] - 1s 7ms/step - loss: 0.1289 - accuracy: 0.9550 - val_loss: 3.6073 - val_accuracy: 0.1879
# Epoch 254/300
# 92/93 [============================>.] - ETA: 0s - loss: 0.1282 - accuracy: 0.9556
# Epoch 00254: val_accuracy did not improve from 0.23693
# 93/93 [==============================] - 1s 7ms/step - loss: 0.1282 - accuracy: 0.9555 - val_loss: 3.5903 - val_accuracy: 0.2006
# Epoch 255/300
# 89/93 [===========================>..] - ETA: 0s - loss: 0.1295 - accuracy: 0.9550
# Epoch 00255: val_accuracy did not improve from 0.23693
# 93/93 [==============================] - 1s 7ms/step - loss: 0.1291 - accuracy: 0.9551 - val_loss: 3.6007 - val_accuracy: 0.1880
# Epoch 256/300
# 91/93 [============================>.] - ETA: 0s - loss: 0.1287 - accuracy: 0.9552
# Epoch 00256: val_accuracy did not improve from 0.23693
# 93/93 [==============================] - 1s 7ms/step - loss: 0.1284 - accuracy: 0.9554 - val_loss: 3.5286 - val_accuracy: 0.2113
# Epoch 257/300
# 89/93 [===========================>..] - ETA: 0s - loss: 0.1291 - accuracy: 0.9552
# Epoch 00257: val_accuracy did not improve from 0.23693
# 93/93 [==============================] - 1s 7ms/step - loss: 0.1291 - accuracy: 0.9551 - val_loss: 3.5698 - val_accuracy: 0.2074
# Epoch 258/300
# 91/93 [============================>.] - ETA: 0s - loss: 0.1278 - accuracy: 0.9556
# Epoch 00258: val_accuracy did not improve from 0.23693
# 93/93 [==============================] - 1s 7ms/step - loss: 0.1280 - accuracy: 0.9556 - val_loss: 3.5496 - val_accuracy: 0.2022
# Epoch 259/300
# 86/93 [==========================>...] - ETA: 0s - loss: 0.1279 - accuracy: 0.9551
# Epoch 00259: val_accuracy did not improve from 0.23693
# 93/93 [==============================] - 1s 7ms/step - loss: 0.1283 - accuracy: 0.9550 - val_loss: 3.5499 - val_accuracy: 0.1889
# Epoch 260/300
# 86/93 [==========================>...] - ETA: 0s - loss: 0.1288 - accuracy: 0.9555
# Epoch 00260: val_accuracy did not improve from 0.23693
# 93/93 [==============================] - 1s 7ms/step - loss: 0.1287 - accuracy: 0.9554 - val_loss: 3.5180 - val_accuracy: 0.2077
# Epoch 261/300
# 90/93 [============================>.] - ETA: 0s - loss: 0.1282 - accuracy: 0.9554
# Epoch 00261: val_accuracy did not improve from 0.23693
# 93/93 [==============================] - 1s 7ms/step - loss: 0.1283 - accuracy: 0.9553 - val_loss: 3.5018 - val_accuracy: 0.2117
# Epoch 262/300
# 88/93 [===========================>..] - ETA: 0s - loss: 0.1281 - accuracy: 0.9557
# Epoch 00262: val_accuracy did not improve from 0.23693
# 93/93 [==============================] - 1s 7ms/step - loss: 0.1281 - accuracy: 0.9557 - val_loss: 3.5258 - val_accuracy: 0.1972
# Epoch 263/300
# 88/93 [===========================>..] - ETA: 0s - loss: 0.1278 - accuracy: 0.9558
# Epoch 00263: val_accuracy did not improve from 0.23693
# 93/93 [==============================] - 1s 7ms/step - loss: 0.1275 - accuracy: 0.9559 - val_loss: 3.5220 - val_accuracy: 0.2154
# Epoch 264/300
# 89/93 [===========================>..] - ETA: 0s - loss: 0.1275 - accuracy: 0.9560
# Epoch 00264: val_accuracy did not improve from 0.23693
# 93/93 [==============================] - 1s 7ms/step - loss: 0.1275 - accuracy: 0.9560 - val_loss: 3.4686 - val_accuracy: 0.2189
# Epoch 265/300
# 88/93 [===========================>..] - ETA: 0s - loss: 0.1280 - accuracy: 0.9556
# Epoch 00265: val_accuracy did not improve from 0.23693
# 93/93 [==============================] - 1s 7ms/step - loss: 0.1281 - accuracy: 0.9556 - val_loss: 3.5256 - val_accuracy: 0.2137
# Epoch 266/300
# 91/93 [============================>.] - ETA: 0s - loss: 0.1278 - accuracy: 0.9560
# Epoch 00266: val_accuracy did not improve from 0.23693
# 93/93 [==============================] - 1s 7ms/step - loss: 0.1278 - accuracy: 0.9560 - val_loss: 3.5260 - val_accuracy: 0.2172
# Epoch 267/300
# 93/93 [==============================] - ETA: 0s - loss: 0.1274 - accuracy: 0.9552
# Epoch 00267: val_accuracy did not improve from 0.23693
# 93/93 [==============================] - 1s 7ms/step - loss: 0.1274 - accuracy: 0.9552 - val_loss: 3.5151 - val_accuracy: 0.2040
# Epoch 268/300
# 87/93 [===========================>..] - ETA: 0s - loss: 0.1281 - accuracy: 0.9556
# Epoch 00268: val_accuracy did not improve from 0.23693
# 93/93 [==============================] - 1s 7ms/step - loss: 0.1278 - accuracy: 0.9559 - val_loss: 3.5101 - val_accuracy: 0.2183
# Epoch 269/300
# 87/93 [===========================>..] - ETA: 0s - loss: 0.1277 - accuracy: 0.9560
# Epoch 00269: val_accuracy did not improve from 0.23693
# 93/93 [==============================] - 1s 7ms/step - loss: 0.1273 - accuracy: 0.9560 - val_loss: 3.4945 - val_accuracy: 0.2233
# Epoch 270/300
# 87/93 [===========================>..] - ETA: 0s - loss: 0.1271 - accuracy: 0.9560
# Epoch 00270: val_accuracy did not improve from 0.23693
# 93/93 [==============================] - 1s 7ms/step - loss: 0.1274 - accuracy: 0.9559 - val_loss: 3.5200 - val_accuracy: 0.1990
# Epoch 271/300
# 87/93 [===========================>..] - ETA: 0s - loss: 0.1285 - accuracy: 0.9556
# Epoch 00271: val_accuracy did not improve from 0.23693
# 93/93 [==============================] - 1s 7ms/step - loss: 0.1280 - accuracy: 0.9558 - val_loss: 3.5320 - val_accuracy: 0.2076
# Epoch 272/300
# 92/93 [============================>.] - ETA: 0s - loss: 0.1283 - accuracy: 0.9553
# Epoch 00272: val_accuracy did not improve from 0.23693
# 93/93 [==============================] - 1s 8ms/step - loss: 0.1283 - accuracy: 0.9553 - val_loss: 3.5131 - val_accuracy: 0.2170
# Epoch 273/300
# 91/93 [============================>.] - ETA: 0s - loss: 0.1270 - accuracy: 0.9559
# Epoch 00273: val_accuracy did not improve from 0.23693
# 93/93 [==============================] - 1s 9ms/step - loss: 0.1268 - accuracy: 0.9560 - val_loss: 3.4767 - val_accuracy: 0.1990
# Epoch 274/300
# 89/93 [===========================>..] - ETA: 0s - loss: 0.1260 - accuracy: 0.9563
# Epoch 00274: val_accuracy did not improve from 0.23693
# 93/93 [==============================] - 1s 8ms/step - loss: 0.1262 - accuracy: 0.9562 - val_loss: 3.4678 - val_accuracy: 0.2206
# Epoch 275/300
# 91/93 [============================>.] - ETA: 0s - loss: 0.1271 - accuracy: 0.9558
# Epoch 00275: val_accuracy did not improve from 0.23693
# 93/93 [==============================] - 1s 9ms/step - loss: 0.1272 - accuracy: 0.9558 - val_loss: 3.4548 - val_accuracy: 0.2140
# Epoch 276/300
# 88/93 [===========================>..] - ETA: 0s - loss: 0.1260 - accuracy: 0.9564
# Epoch 00276: val_accuracy did not improve from 0.23693
# 93/93 [==============================] - 1s 8ms/step - loss: 0.1263 - accuracy: 0.9563 - val_loss: 3.4442 - val_accuracy: 0.2240
# Epoch 277/300
# 90/93 [============================>.] - ETA: 0s - loss: 0.1264 - accuracy: 0.9561
# Epoch 00277: val_accuracy did not improve from 0.23693
# 93/93 [==============================] - 1s 8ms/step - loss: 0.1264 - accuracy: 0.9561 - val_loss: 3.4326 - val_accuracy: 0.2257
# Epoch 278/300
# 89/93 [===========================>..] - ETA: 0s - loss: 0.1268 - accuracy: 0.9562
# Epoch 00278: val_accuracy did not improve from 0.23693
# 93/93 [==============================] - 1s 10ms/step - loss: 0.1267 - accuracy: 0.9562 - val_loss: 3.4923 - val_accuracy: 0.2050
# Epoch 279/300
# 86/93 [==========================>...] - ETA: 0s - loss: 0.1270 - accuracy: 0.9560
# Epoch 00279: val_accuracy did not improve from 0.23693
# 93/93 [==============================] - 1s 9ms/step - loss: 0.1268 - accuracy: 0.9560 - val_loss: 3.4195 - val_accuracy: 0.2278
# Epoch 280/300
# 89/93 [===========================>..] - ETA: 0s - loss: 0.1261 - accuracy: 0.9565
# Epoch 00280: val_accuracy did not improve from 0.23693
# 93/93 [==============================] - 1s 12ms/step - loss: 0.1263 - accuracy: 0.9565 - val_loss: 3.4515 - val_accuracy: 0.2254
# Epoch 281/300
# 92/93 [============================>.] - ETA: 0s - loss: 0.1267 - accuracy: 0.9558
# Epoch 00281: val_accuracy did not improve from 0.23693
# 93/93 [==============================] - 1s 10ms/step - loss: 0.1266 - accuracy: 0.9558 - val_loss: 3.4758 - val_accuracy: 0.2172
# Epoch 282/300
# 88/93 [===========================>..] - ETA: 0s - loss: 0.1268 - accuracy: 0.9560
# Epoch 00282: val_accuracy did not improve from 0.23693
# 93/93 [==============================] - 1s 9ms/step - loss: 0.1266 - accuracy: 0.9560 - val_loss: 3.5261 - val_accuracy: 0.2049
# Epoch 283/300
# 93/93 [==============================] - ETA: 0s - loss: 0.1266 - accuracy: 0.9559
# Epoch 00283: val_accuracy did not improve from 0.23693
# 93/93 [==============================] - 1s 8ms/step - loss: 0.1266 - accuracy: 0.9559 - val_loss: 3.4349 - val_accuracy: 0.2097
# Epoch 284/300
# 91/93 [============================>.] - ETA: 0s - loss: 0.1269 - accuracy: 0.9565
# Epoch 00284: val_accuracy did not improve from 0.23693
# 93/93 [==============================] - 1s 9ms/step - loss: 0.1268 - accuracy: 0.9566 - val_loss: 3.5256 - val_accuracy: 0.1906
# Epoch 285/300
# 93/93 [==============================] - ETA: 0s - loss: 0.1265 - accuracy: 0.9560
# Epoch 00285: val_accuracy did not improve from 0.23693
# 93/93 [==============================] - 1s 8ms/step - loss: 0.1265 - accuracy: 0.9560 - val_loss: 3.5215 - val_accuracy: 0.1921
# Epoch 286/300
# 93/93 [==============================] - ETA: 0s - loss: 0.1264 - accuracy: 0.9565
# Epoch 00286: val_accuracy did not improve from 0.23693
# 93/93 [==============================] - 1s 9ms/step - loss: 0.1264 - accuracy: 0.9565 - val_loss: 3.4917 - val_accuracy: 0.1796
# Epoch 287/300
# 88/93 [===========================>..] - ETA: 0s - loss: 0.1261 - accuracy: 0.9564
# Epoch 00287: val_accuracy did not improve from 0.23693
# 93/93 [==============================] - 1s 8ms/step - loss: 0.1264 - accuracy: 0.9563 - val_loss: 3.4370 - val_accuracy: 0.2251
# Epoch 288/300
# 89/93 [===========================>..] - ETA: 0s - loss: 0.1253 - accuracy: 0.9567
# Epoch 00288: val_accuracy did not improve from 0.23693
# 93/93 [==============================] - 1s 8ms/step - loss: 0.1247 - accuracy: 0.9569 - val_loss: 3.4366 - val_accuracy: 0.2170
# Epoch 289/300
# 90/93 [============================>.] - ETA: 0s - loss: 0.1259 - accuracy: 0.9565
# Epoch 00289: val_accuracy did not improve from 0.23693
# 93/93 [==============================] - 1s 8ms/step - loss: 0.1259 - accuracy: 0.9565 - val_loss: 3.4999 - val_accuracy: 0.1874
# Epoch 290/300
# 90/93 [============================>.] - ETA: 0s - loss: 0.1256 - accuracy: 0.9562
# Epoch 00290: val_accuracy improved from 0.23693 to 0.23983, saving model to D:\Download\zyFile\Cyberthreat_Cognitive_System\CTCS_Code\attack_datasets\NSL-KDD\Model\NSL-KDD\AUG\LSTM\Mix_dataset_Label_Encoding_LDA_SMOTE.h5
# 93/93 [==============================] - 1s 8ms/step - loss: 0.1255 - accuracy: 0.9563 - val_loss: 3.4305 - val_accuracy: 0.2398
# Epoch 291/300
# 89/93 [===========================>..] - ETA: 0s - loss: 0.1258 - accuracy: 0.9562
# Epoch 00291: val_accuracy did not improve from 0.23983
# 93/93 [==============================] - 1s 8ms/step - loss: 0.1262 - accuracy: 0.9561 - val_loss: 3.4963 - val_accuracy: 0.2083
# Epoch 292/300
# 92/93 [============================>.] - ETA: 0s - loss: 0.1265 - accuracy: 0.9563
# Epoch 00292: val_accuracy did not improve from 0.23983
# 93/93 [==============================] - 1s 8ms/step - loss: 0.1267 - accuracy: 0.9563 - val_loss: 3.5466 - val_accuracy: 0.2032
# Epoch 293/300
# 89/93 [===========================>..] - ETA: 0s - loss: 0.1265 - accuracy: 0.9561
# Epoch 00293: val_accuracy did not improve from 0.23983
# 93/93 [==============================] - 1s 9ms/step - loss: 0.1263 - accuracy: 0.9562 - val_loss: 3.4773 - val_accuracy: 0.2055
# Epoch 294/300
# 91/93 [============================>.] - ETA: 0s - loss: 0.1261 - accuracy: 0.9564
# Epoch 00294: val_accuracy did not improve from 0.23983
# 93/93 [==============================] - 1s 8ms/step - loss: 0.1259 - accuracy: 0.9565 - val_loss: 3.4509 - val_accuracy: 0.2185
# Epoch 295/300
# 86/93 [==========================>...] - ETA: 0s - loss: 0.1251 - accuracy: 0.9566
# Epoch 00295: val_accuracy did not improve from 0.23983
# 93/93 [==============================] - 1s 8ms/step - loss: 0.1252 - accuracy: 0.9567 - val_loss: 3.4743 - val_accuracy: 0.2024
# Epoch 296/300
# 89/93 [===========================>..] - ETA: 0s - loss: 0.1258 - accuracy: 0.9566
# Epoch 00296: val_accuracy did not improve from 0.23983
# 93/93 [==============================] - 1s 8ms/step - loss: 0.1257 - accuracy: 0.9566 - val_loss: 3.4804 - val_accuracy: 0.2181
# Epoch 297/300
# 92/93 [============================>.] - ETA: 0s - loss: 0.1255 - accuracy: 0.9565
# Epoch 00297: val_accuracy did not improve from 0.23983
# 93/93 [==============================] - 1s 8ms/step - loss: 0.1255 - accuracy: 0.9565 - val_loss: 3.4624 - val_accuracy: 0.2098
# Epoch 298/300
# 91/93 [============================>.] - ETA: 0s - loss: 0.1262 - accuracy: 0.9562
# Epoch 00298: val_accuracy did not improve from 0.23983
# 93/93 [==============================] - 1s 8ms/step - loss: 0.1260 - accuracy: 0.9562 - val_loss: 3.4727 - val_accuracy: 0.2078
# Epoch 299/300
# 88/93 [===========================>..] - ETA: 0s - loss: 0.1247 - accuracy: 0.9562
# Epoch 00299: val_accuracy did not improve from 0.23983
# 93/93 [==============================] - 1s 8ms/step - loss: 0.1246 - accuracy: 0.9563 - val_loss: 3.3955 - val_accuracy: 0.2168
# Epoch 300/300
# 86/93 [==========================>...] - ETA: 0s - loss: 0.1256 - accuracy: 0.9564
# Epoch 00300: val_accuracy did not improve from 0.23983
# 93/93 [==============================] - 1s 8ms/step - loss: 0.1259 - accuracy: 0.9563 - val_loss: 3.4580 - val_accuracy: 0.2095

# %%
# from tensorflow.python.keras.models import load_model
# model = load_model(r"D:\Download\zyFile\Cyberthreat_Cognitive_System\CTCS_Code\attack_datasets\NSL-KDD\Model\NSL-KDD\AUG\LSTM\Mix_dataset_One_Hot_PCA_ADASYN.h5")
# 预测测试集
y_pred = model.predict(x_test)
# 计算测试集上的损失值和准确率
test_loss, test_acc = model.evaluate(x_test, y_test, verbose=0)
print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_acc*100:.2f}")
# Out:
# Test Loss: 0.1327
# Test Accuracy: 95.45

# %%
# 准确率曲线
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.axhline(y=test_acc, color='g', linestyle='--', label='Test Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# 损失曲线
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.axhline(y=test_loss, color='g', linestyle='--', label='Test Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, confusion_matrix, roc_curve, auc, matthews_corrcoef
from keras.utils import np_utils
import numpy as np
import matplotlib.pyplot as plt

label_mapping = ['normal', 'dos', 'probe', 'r2l', 'u2r']
class_names = label_mapping

# Assuming y_pred is the raw output predictions from the model, you need to convert these to class labels for some metrics
# Convert probabilities to class labels
y_pred_classes = np.argmax(y_pred, axis=1)
y_test_classes = np.argmax(y_test, axis=1)  # Assuming y_test is already one-hot encoded, convert it back

# Generate confusion matrix
conf_matrix = confusion_matrix(y_test_classes, y_pred_classes)

# Visualize confusion matrix
plt.figure(figsize=(10, 7))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()

# %%
# Calculate metrics
recall = recall_score(y_test_classes, y_pred_classes, average='macro')
precision = precision_score(y_test_classes, y_pred_classes, average='macro')
f1 = f1_score(y_test_classes, y_pred_classes, average='macro')

# 定义FAR分数计算函数
def far_score(y_true, y_pred, normal_label):
    # 生成混淆矩阵
    cm = confusion_matrix(y_true, y_pred)
    # 获取正常流量的索引
    normal_index = list(np.unique(y_true)).index(normal_label)
    # 初始化FAR分数列表
    far_scores = []
    # 遍历所有类别，计算每个攻击类别的FAR
    for i in range(len(cm)):
        if i != normal_index:  # 跳过正常流量类别
            tn = cm[i, i]  # 真负例（攻击被正确识别为攻击）
            fp = cm[i, normal_index]  # 假正例（攻击被识别为正常）
            far = fp / (fp + tn) if (fp + tn) != 0 else 0  # 计算FAR
            far_scores.append(far)  # 将FAR添加到列表中
    # 返回所有攻击类别FAR的平均值
    return np.mean(far_scores) if far_scores else 0

far = far_score(y_test_classes, y_pred_classes, normal_label=0)

# Function to calculate MCC for a binary classification problem
# Adapted for multi-class by averaging over all classes
def mcc_score(y_true, y_pred):
    mcc = np.array([matthews_corrcoef(y_true == k, y_pred == k) for k in np.unique(y_true)])
    return np.nanmean(mcc)  # Averaging MCC scores over all classes

average_mcc = mcc_score(y_test_classes, y_pred_classes)

# Convert metrics to percentages
# 转换为百分数并保留两位小数
recall_percent = f"{recall * 100:.2f}%"
precision_percent = f"{precision * 100:.2f}%"
f1_percent = f"{f1 * 100:.2f}%"
far_percent = f"{(far) * 100:.2f}%"
average_mcc_percent = f"{average_mcc * 100:.2f}%"

print(f"Average Precision: {precision_percent}")
print(f"Average Recall: {recall_percent}")
print(f"Average F1 Score: {f1_percent}")
print(f"Average MCC: {average_mcc_percent}")
print(f"Average False Acceptance Rate: {far_percent}")
# Out:
# Average Precision: 80.85%
# Average Recall: 80.98%
# Average F1 Score: 77.04%
# Average MCC: 77.54%
# Average False Acceptance Rate: 11.35%

# %%
from sklearn.metrics import roc_curve, auc
from scipy import interp
from sklearn.preprocessing import label_binarize
import matplotlib.pyplot as plt
from itertools import cycle

# 如果y_test不是one-hot编码的，先将其转换
y_test_binarized = label_binarize(y_test_classes, classes=np.unique(y_test_classes))
n_classes = y_test_binarized.shape[1]

# 计算每个类的ROC曲线和ROC面积
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test_binarized[:, i], y_pred[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# 绘制所有类的ROC曲线
plt.figure(figsize=(10, 10))
colors = cycle(['aqua', 'darkorange', 'cornflowerblue', 'deeppink', 'navy'])
for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=2,
             label='Class {0} (area = {1:0.4f})'.format(class_names[i], roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--', lw=2)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Multi-class ROC Curve')
# 将图例放到图像外面并放大字体
plt.legend(loc='lower right', fontsize='25')
# 调整布局以防止图例被裁剪
plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import precision_recall_curve, auc
from sklearn.preprocessing import label_binarize
import matplotlib.pyplot as plt
import numpy as np

# 假设您已经有了y_pred，这是模型对测试集的预测概率
# 如果y_pred不是概率分数，请用model.predict(x_test)替换下面的y_score
y_score = y_pred  # 确保这是一个概率分数矩阵

# 将真实标签转换为 one-hot 编码
# 注意这里y_test_classes是真实的类标签，需要转换为one-hot编码形式
y_true_bin = label_binarize(y_test_classes, classes=np.unique(y_test_classes))

# 确定类别数和类别名称
n_classes = y_true_bin.shape[1]
class_names = ['normal', 'dos', 'probe', 'r2l', 'u2r']  # 举例，根据实际情况调整
    
# 创建一个新的图表
plt.figure(figsize=(10, 10))

# 为每个类别绘制PR曲线，并记录AUC值
auc_scores = []
for i in range(n_classes):
    precision, recall, _ = precision_recall_curve(y_true_bin[:, i], y_score[:, i])
    auc_score = auc(recall, precision)
    auc_scores.append(auc_score)
    plt.plot(recall, precision, marker='.', label='Class {} (AUC = {:.4f})'.format(class_names[i], auc_score))

# 设置图表的其他属性
plt.title('Precision-Recall Curve for Multiple Classes')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.legend(fontsize=14)
# 将图例放置在图像的右侧外部
plt.legend(bbox_to_anchor=(1, 1), fontsize=14)
# 展示图表
plt.show()
